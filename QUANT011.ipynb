# %% [markdown]
# <a href="https://colab.research.google.com/github/wannasmile/colab_code_note/blob/main/QUANT011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta akshare
# Out:
# ...
# WARNING: akracer 0.0.13 does not provide the extra 'py-mini-racer'
# ...

# %%
import akshare as ak

stock_hk_index_spot_em_df = ak.stock_hk_index_spot_em()
print(stock_hk_index_spot_em_df)
# Out:
#       序号 内部编号        代码              名称      最新价     涨跌额   涨跌幅       今开  \
# 0      1  124    HST2SI      恒生科指2倍短仓指数   188.86   10.84  6.09   181.92
# 1      2  124  HSTECF2S   恒生科技指期货2倍短仓指数   856.80   48.53  6.00   826.87
# 2      3  124  HSCEI2SI      恒生国企2倍短仓指数   745.21   24.12  3.34   733.65
# 3      4  124    HSI2SI        恒指2倍短仓指数   161.45    5.05  3.23   159.55
# 4      5  124   HSTECHS        恒生科指短仓指数   501.80   14.87  3.05   492.31
# ..   ...  ...       ...             ...      ...     ...   ...      ...
# 366  367  124     HSTCC    恒生科指备兑认购期权指数  2232.34  -84.91 -3.66  2279.85
# 367  368  124      HSME          恒生传媒指数  2737.46 -104.86 -3.69  2803.29
# 368  369  124  HSTECF2L   恒生科技指期货2倍杠杆指数   599.12  -38.15 -5.99   622.72
# 369  370  124    HST2LT  恒生科指股息累计2倍杠杆指数  2978.26 -193.12 -6.09  3102.26
# 370  371  124  HSTECH2L      恒生科指2倍杠杆指数  2436.41 -157.99 -6.09  2537.85
#
#           最高       最低       昨收  成交量           成交额
# 0     190.97   179.34   178.02  0.0           NaN
# ...

# %%
import pandas as pd
import requests
url = "https://tsanghi.com/api/fin/index/HKG/15min?token=demo&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_15min_pandas_demo.csv', index=False, encoding='utf-8')

print(df)
# Out:
#    ticker                 date     open     high      low    close  \
# 0  HSTECH  2025-01-21 10:30:00  4644.18  4653.66  4642.80  4653.23
# 1  HSTECH  2025-01-22 11:00:00  4609.80  4622.22  4601.41  4619.98
# 2  HSTECH  2025-01-24 13:30:00  4653.33  4669.59  4653.28  4662.16
# 3  HSTECH  2025-02-03 14:00:00  4678.50  4705.64  4676.59  4704.48
# 4  HSTECH  2025-02-04 10:45:00  4966.01  4975.00  4947.40  4947.73
# 5  HSTECH  2025-02-05 15:30:00  4925.09  4933.01  4923.48  4931.51
# 6  HSTECH  2025-02-10 11:00:00  5235.24  5257.31  5232.68  5248.71
# 7  HSTECH  2025-02-12 14:15:00  5236.44  5250.72  5230.19  5241.05
# 8  HSTECH  2025-02-13 14:45:00  5409.18  5418.12  5335.04  5335.43
# 9  HSTECH  2025-02-14 11:00:00  5361.75  5400.64  5360.90  5380.40
#
#         volume
# 0    7261192.0
# 1    6649610.0
# 2    6454105.0
# 3    7151821.0
# 4   13457152.0
# 5    9529245.0
# 6   12076879.0
# 7   77111943.0
# 8  293384105.0
# 9  183115721.0

# %%
import csv
import requests

url = "https://tsanghi.com/api/fin/index/HKG/5min?token=demo&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']  # 提取字典列表

# 定义CSV表头（与字典键一致）
fieldnames = ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume']

with open('hstech_data_5min_demo.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()      # 写入表头
    writer.writerows(data_list)  # 批量写入所有数据


import pandas as pd
import requests

url = "https://tsanghi.com/api/fin/index/HKG/5min?token=demo&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_5min_pandas_demo.csv', index=False, encoding='utf-8')

print(df)
# Out:
#    ticker                 date     open     high      low    close     volume
# 0  HSTECH  2025-01-20 15:30:00  4596.93  4597.13  4589.43  4589.85  2945701.0
# 1  HSTECH  2025-01-20 15:50:00  4591.81  4593.64  4584.89  4584.89  3414721.0
# 2  HSTECH  2025-01-21 13:10:00  4706.37  4715.56  4700.45  4714.99  3143453.0
# 3  HSTECH  2025-01-21 14:20:00  4689.26  4692.17  4681.85  4682.53  1888592.0
# 4  HSTECH  2025-01-22 11:05:00  4620.06  4628.39  4613.20  4613.51  1862616.0
# 5  HSTECH  2025-01-22 14:55:00  4570.12  4571.62  4566.31  4566.40  1862062.0
# 6  HSTECH  2025-01-23 11:35:00  4580.91  4586.32  4580.46  4585.60   837263.0
# 7  HSTECH  2025-01-24 11:40:00  4624.56  4632.78  4623.96  4632.37  1144190.0
# 8  HSTECH  2025-01-24 13:05:00  4642.40  4649.75  4631.14  4632.19  3812985.0
# 9  HSTECH  2025-01-27 15:20:00  4703.43  4703.43  4692.15  4693.50  2420878.0

# %%
import requests
url = "https://tsanghi.com/api/fin/index/HKG/15min?token=demo&ticker=HSTECH"
data = requests.get(url).json()
print(data)
# Out:
# {'msg': '操作成功', 'code': 200, 'data': [{'ticker': 'HSTECH', 'date': '2025-01-20 13:30:00', 'open': 4625.58, 'high': 4638.4, 'low': 4624.41, 'close': 4630.06, 'volume': 7430307.0}, {'ticker': 'HSTECH', 'date': '2025-01-21 13:45:00', 'open': 4683.29, 'high': 4695.14, 'low': 4683.29, 'close': 4685.21, 'volume': 4406777.0}, {'ticker': 'HSTECH', 'date': '2025-01-24 10:45:00', 'open': 4607.12, 'high': 4642.6, 'low': 4607.12, 'close': 4626.53, 'volume': 11485178.0}, {'ticker': 'HSTECH', 'date': '2025-02-03 11:15:00', 'open': 4631.55, 'high': 4662.84, 'low': 4630.67, 'close': 4662.71, 'volume': 8128827.0}, {'ticker': 'HSTECH', 'date': '2025-02-05 11:00:00', 'open': 4906.29, 'high': 4945.99, 'low': 4906.29, 'close': 4945.05, 'volume': 20418571.0}, {'ticker': 'HSTECH', 'date': '2025-02-06 13:15:00', 'open': 4977.23, 'high': 5020.79, 'low': 4977.23, 'close': 5019.3, 'volume': 11797361.0}, {'ticker': 'HSTECH', 'date': '2025-02-07 10:45:00', 'open': 5144.31, 'high': 5147.52, 'low': 5115.76, 'close
# ...

# %%
import pandas as pd
import requests

#https://tsanghi.com/api/fin/index/{country_code}/daily?token={token}&ticker={ticker}

url = "https://tsanghi.com/api/fin/index/HKG/daily?token=demo&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_daily_pandas_demo.csv', index=False, encoding='utf-8')

print(df)
# Out:
#    ticker        date     open     high      low    close       volume
# 0  HSTECH  2024-05-16  4091.59  4097.82  4024.42  4072.15   13938400.0
# 1  HSTECH  2024-08-28  3478.90  3488.30  3425.73  3445.46          0.0
# 2  HSTECH  2025-01-13  4222.99  4238.00  4168.04  4221.92  156554282.0
# 3  HSTECH  2024-05-13  3925.19  4031.09  3906.36  4018.69    8415152.0
# 4  HSTECH  2024-08-06  3392.21  3409.60  3322.30  3342.52          0.0
# 5  HSTECH  2024-09-03  3486.02  3534.69  3472.02  3496.49          0.0
# 6  HSTECH  2024-10-15  4654.12  4682.83  4405.29  4450.95          0.0
# 7  HSTECH  2024-11-06  4646.37  4667.90  4525.36  4574.50          0.0
# 8  HSTECH  2024-12-30  4546.01  4557.06  4484.78  4500.60  154870949.0
# 9  HSTECH  2024-03-20  3538.65  3569.97  3493.75  3551.42    5290899.0

# %%
import pandas as pd
import requests

url = "https://tsanghi.com/api/fin/index/HKG/daily?token=f091905e648d4832af9a533c36d211d5&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_1d.csv', index=False, encoding='utf-8')

print(df)
# Out:
#      ticker        date     open     high      low    close       volume
# 0    HSTECH  2024-04-11  3480.30  3553.46  3480.30  3538.39    6268658.0
# 1    HSTECH  2024-07-25  3461.91  3467.24  3408.05  3421.26          0.0
# 2    HSTECH  2024-09-24  3785.98  3916.69  3755.15  3915.58          0.0
# 3    HSTECH  2024-10-04  4941.96  5233.98  4885.22  5227.13          0.0
# 4    HSTECH  2024-11-19  4381.92  4413.08  4341.87  4395.04          0.0
# ..      ...         ...      ...      ...      ...      ...          ...
# 241  HSTECH  2024-08-06  3392.21  3409.60  3322.30  3342.52          0.0
# 242  HSTECH  2024-09-03  3486.02  3534.69  3472.02  3496.49          0.0
# 243  HSTECH  2024-10-15  4654.12  4682.83  4405.29  4450.95          0.0
# 244  HSTECH  2024-11-06  4646.37  4667.90  4525.36  4574.50          0.0
# 245  HSTECH  2024-12-30  4546.01  4557.06  4484.78  4500.60  154870949.0
#
# [246 rows x 7 columns]

# %%
# 将 df 转换为 JSON 字符串
json_data = df.to_json(orient='records')  # orient='records' 将数据转换为 JSON 数组

# 将 JSON 字符串保存到文件
with open('data.json', 'w', encoding='utf-8') as f:
    f.write(json_data)

print("数据已保存到 data.json")
# Out:
# 数据已保存到 data.json

# %%
import pandas as pd
json_hstech_data_1d = """
[{"ticker":"HSTECH","date":"2024-03-05","open":3381.88,"high":3401.93,"low":3317.12,"close":3323.89,"volume":9336947.0},{"ticker":"HSTECH","date":"2024-03-15","open":3534.14,"high":3550.19,"low":3487.71,"close":3549.84,"volume":9856584.0},{"ticker":"HSTECH","date":"2024-04-02","open":3558.92,"high":3577.39,"low":3525.09,"close":3543.12,"volume":11087920.0},{"ticker":"HSTECH","date":"2024-07-03","open":3564.64,"high":3638.23,"low":3553.24,"close":3626.93,"volume":7769696.0},{"ticker":"HSTECH","date":"2024-07-23","open":3634.67,"high":3639.61,"low":3537.28,"close":3545.09,"volume":0.0},{"ticker":"HSTECH","date":"2024-07-26","open":3443.65,"high":3476.47,"low":3410.75,"close":3443.73,"volume":0.0},{"ticker":"HSTECH","date":"2024-09-02","open":3539.86,"high":3539.86,"low":3477.95,"close":3486.4,"volume":0.0},{"ticker":"HSTECH","date":"2024-11-07","open":4532.54,"high":4687.5,"low":4508.4,"close":4677.64,"volume":0.0},{"ticker":"HSTECH","date":"2024-11
"volume":0.0},{"ticker":"HSTECH","date":"2025-02-17","open":5599.12,"high":5656.44,"low":5394.26,"close":5499.26,"volume":4636067406.0},{"ticker":"HSTECH","date":"2024-04-24","open":3495.13,"high":3577.58,"low":3474.89,"close":3573.59,"volume":12521203.0},{"ticker":"HSTECH","date":"2024-06-21","open":3720.72,"high":3734.62,"low":3674.31,"close":3701.4,"volume":9303692.0},{"ticker":"HSTECH","date":"2024-08-20","open":3556.74,"high":3556.74,"low":3484.92,"close":3498.08,"volume":0.0},{"ticker":"HSTECH","date":"2024-11-05","open":4486.17,"high":4694.48,"low":4486.17,"close":4693.85,"volume":0.0},{"ticker":"HSTECH","date":"2025-01-23","open":4615.0,"high":4659.78,"low":4496.56,"close":4515.48,"volume":145774694.0}]
"""

data_list = pd.read_json(json_hstech_data_1d)

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_1d.csv', index=False, encoding='utf-8')

print(df)
# Out:
#      ticker       date     open     high      low    close     volume
# 0    HSTECH 2024-03-05  3381.88  3401.93  3317.12  3323.89    9336947
# 1    HSTECH 2024-03-15  3534.14  3550.19  3487.71  3549.84    9856584
# 2    HSTECH 2024-04-02  3558.92  3577.39  3525.09  3543.12   11087920
# 3    HSTECH 2024-07-03  3564.64  3638.23  3553.24  3626.93    7769696
# 4    HSTECH 2024-07-23  3634.67  3639.61  3537.28  3545.09          0
# ..      ...        ...      ...      ...      ...      ...        ...
# 241  HSTECH 2024-04-24  3495.13  3577.58  3474.89  3573.59   12521203
# 242  HSTECH 2024-06-21  3720.72  3734.62  3674.31  3701.40    9303692
# 243  HSTECH 2024-08-20  3556.74  3556.74  3484.92  3498.08          0
# 244  HSTECH 2024-11-05  4486.17  4694.48  4486.17  4693.85          0
# 245  HSTECH 2025-01-23  4615.00  4659.78  4496.56  4515.48  145774694
#
# [246 rows x 7 columns]
# ...

# %%
import pandas as pd
import requests

url = "https://tsanghi.com/api/fin/index/HKG/5min?token=f091905e648d4832af9a533c36d211d5&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_5min.csv', index=False, encoding='utf-8')

print(df)
# Out:
#      ticker                 date     open     high      low    close  \
# 0    HSTECH  2025-01-20 15:25:00  4595.28  4597.43  4594.08  4597.04
# 1    HSTECH  2025-01-21 13:15:00  4714.15  4716.77  4705.01  4705.31
# 2    HSTECH  2025-01-21 14:35:00  4681.62  4684.31  4670.91  4684.09
# 3    HSTECH  2025-01-21 15:00:00  4682.53  4688.76  4681.60  4688.67
# 4    HSTECH  2025-01-22 11:45:00  4600.79  4601.63  4597.77  4599.93
# ..      ...                  ...      ...      ...      ...      ...
# 995  HSTECH  2025-02-04 13:55:00  4930.21  4940.87  4922.40  4922.57
# 996  HSTECH  2025-02-04 15:40:00  4967.28  4972.09  4967.28  4971.10
# 997  HSTECH  2025-02-05 10:25:00  4893.77  4896.46  4883.16  4892.17
# 998  HSTECH  2025-02-05 14:35:00  4925.82  4929.45  4918.24  4919.13
# 999  HSTECH  2025-02-06 13:40:00  4996.36  4996.36  4987.01  4987.01
#
#         volume
# 0    1491482.0
# 1    2646952.0
# 2    2571342.0
# 3    1494794.0
# 4    1054030.0
# ..         ...
# 995  2908033.0
# ...

# %%
# 将 df 转换为 JSON 字符串
json_data = df.to_json(orient='records')  # orient='records' 将数据转换为 JSON 数组

# 将 JSON 字符串保存到文件
with open('data.json', 'w', encoding='utf-8') as f:
# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_5min.csv', index=False, encoding='utf-8')

print(df)
# Out:
#      ticker                date     open     high      low    close   volume
# 0    HSTECH 2025-01-20 11:55:00  4619.10  4628.07  4618.67  4624.13  2866940
# 1    HSTECH 2025-01-21 09:40:00  4630.42  4631.11  4610.22  4622.71  7334511
# 2    HSTECH 2025-01-21 10:45:00  4657.66  4657.79  4645.50  4645.50  2012679
# 3    HSTECH 2025-01-21 13:55:00  4681.47  4682.09  4666.82  4668.08  2069230
# 4    HSTECH 2025-01-22 13:40:00  4579.06  4582.77  4573.77  4575.51  1438958
# ..      ...                 ...      ...      ...      ...      ...      ...
# 995  HSTECH 2025-01-24 11:15:00  4630.25  4638.53  4627.24  4636.40  2505383
# 996  HSTECH 2025-01-24 13:50:00  4669.06  4675.81  4663.91  4667.12  2085390
# 997  HSTECH 2025-01-28 09:45:00  4714.07  4722.51  4707.59  4715.53  2654821
# 998  HSTECH 2025-01-28 09:55:00  4706.54  4722.28  4706.54  4712.30  2908292
# 999  HSTECH 2025-01-28 13:05:00  4726.14  4726.14  4726.14  4726.14        0
#
# [1000 rows x 7 columns]
# ...

# %%
import pandas as pd
import requests

url = "https://tsanghi.com/api/fin/index/HKG/15min?token=f091905e648d4832af9a533c36d211d5&ticker=HSTECH"
response = requests.get(url)
data_list = response.json()['data']

# 将字典列表转为DataFrame并导出为CSV
df = pd.DataFrame(data_list)
df.to_csv('hstech_data_15min.csv', index=False, encoding='utf-8')

print(df)
# Out:
#      ticker                 date     open     high      low    close  \
# 0    HSTECH  2025-01-20 14:30:00  4604.07  4605.68  4588.58  4592.36
# 1    HSTECH  2025-01-21 11:45:00  4706.55  4709.89  4698.63  4702.18
# 2    HSTECH  2025-01-21 15:15:00  4688.46  4702.94  4687.00  4701.73
# 3    HSTECH  2025-01-22 12:00:00  4599.81  4603.35  4596.28  4601.09
# 4    HSTECH  2025-01-22 15:00:00  4571.25  4571.62  4564.97  4569.10
# ..      ...                  ...      ...      ...      ...      ...
# 457  HSTECH  2025-02-13 11:45:00  5340.03  5362.18  5338.96  5355.28
# 458  HSTECH  2025-02-13 14:15:00  5466.85  5503.40  5466.85  5475.97
# 459  HSTECH  2025-02-13 15:00:00  5335.85  5368.61  5331.84  5332.98
# 460  HSTECH  2025-02-17 10:45:00  5543.67  5573.16  5543.38  5556.71
# 461  HSTECH  2025-02-18 15:45:00  5601.24  5614.13  5599.52  5607.32
#
#           volume
# 0      7815589.0
# 1      4266155.0
# 2      5655703.0
# 3      3039866.0
# 4      5005807.0
# ..           ...
# ...

# %%
# 将 df 转换为 JSON 字符串
json_data = df.to_json(orient='records')  # orient='records' 将数据转换为 JSON 数组

# 将 JSON 字符串保存到文件
with open('data.json', 'w', encoding='utf-8') as f:
    f.write(json_data)

print("数据已保存到 data.json")
# Out:
# 数据已保存到 data.json

# %%
import pandas as pd
json_hstech_data_15min = """
[{"ticker":"HSTECH","date":"2025-01-20 12:00:00","open":4618.94,"high":4628.07,"low":4617.8,"close":4621.0,"volume":6393899.0},{"ticker":"HSTECH","date":"2025-01-21 14:00:00","open":4685.82,"high":4689.23,"low":4666.82,"close":4674.56,"volume":5265747.0},{"ticker":"HSTECH","date":"2025-01-21 15:45:00","open":4697.35,"high":4704.75,"low":4690.27,"close":4695.8,"volume":9333831.0},{"ticker":"HSTECH","date":"2025-01-22 13:45:00","open":
# * 处理重复时间戳和缺失值
#
# * 支持自动扩展历史数据周期
#
# 2. 分析方法增强：
#
# * 五因子综合模型：整数关口、斐波那契、布林带、波动率通道、近期高低点
#
# * 加入机器学习聚类算法（K-means）过滤冗余点位
#
# * 动态ATR（平均真实波幅）通道计算
#
# * 自适应窗口滚动计算（根据数据量自动调整参数）

# %%
from scipy.signal import argrelextrema
from sklearn.cluster import KMeans
import numpy as np  # 导入numpy库
import pandas as pd

class HSTechAnalyzer:
    def __init__(self):
        # 加载数据
        self.daily_df = self._load_data('hstech_data_1d.csv', '1D')
        self.hourly_df = self._resample_to_hourly('hstech_data_5min.csv')

    def _load_data(self, path, freq):
        """加载并预处理数据"""
        df = pd.read_csv(path, parse_dates=['date'])
        df = df.sort_values('date').set_index('date')
        df = df[~df.index.duplicated(keep='first')]
        return df.resample(freq).agg({
            'open': 'first',
            'high': 'max',
            'low': 'min',
            'close': 'last',
            'volume': 'sum'
        }).dropna()

    def _resample_to_hourly(self, path):
        """将5分钟数据转为小时数据"""
        df = pd.read_csv(path, parse_dates=['date'])
        df = df.sort_values('date').set_index('date')
        return df.resample('1h').agg({
            'open': 'first',
            'high': 'max',
            'low': 'min',
            'close': 'last',
            'volume': 'sum'
        }).dropna()

    def _find_pivots(self, prices, window=5):
        """识别关键拐点"""
        max_idx = argrelextrema(prices.values, np.greater, order=window)[0]
        min_idx = argrelextrema(prices.values, np.less, order=window)[0]
        return sorted(prices.iloc[max_idx].tolist() + prices.iloc[min_idx].tolist())

    def _fibonacci_levels(self, df, lookback=20):
        """斐波那契回撤位计算"""
        recent = df.iloc[-lookback:]
        swing_high = recent['high'].max()
        swing_low = recent['low'].min()
        delta = swing_high - swing_low
        return {
            0.236: swing_high - delta * 0.236,
            0.382: swing_high - delta * 0.382,
            0.5: swing_high - delta * 0.5,
            0.618: swing_high - delta * 0.618,
            0.786: swing_high - delta * 0.786
        }

    def _cluster_levels(self, levels):
        """使用K-means聚类关键点位"""
        if len(levels) < 3:
            return sorted(levels)
        X = np.array(levels).reshape(-1,1)
        kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
        return sorted([round(x[0],2) for x in kmeans.cluster_centers_])

    def calculate_support_resistance(self, df, freq='daily'):
        """综合计算支撑压力位"""
        methods = {}

        # 方法1：整数关口
        current_price = df['close'].iloc[-1]
        methods['round_number'] = {
            'support': [np.floor(current_price / 100) * 100],
            'resistance': [np.ceil(current_price / 100) * 100]
        }

        # 方法2：近期高低点
        methods['recent_extreme'] = {
            'support': [df['low'].rolling(20).min().iloc[-1]],
            'resistance': [df['high'].rolling(20).max().iloc[-1]]
        }

        # 方法3：斐波那契
        fib = self._fibonacci_levels(df)
        methods['fibonacci'] = {
            'support': [fib[0.618]],
            'resistance': [fib[0.382]]
        }

        # 方法4：布林带
        ma20 = df['close'].rolling(20).mean()
        std = df['close'].rolling(20).std()
        methods['bollinger'] = {
            'support': [ma20.iloc[-1] - 2*std.iloc[-1]],
            'resistance': [ma20.iloc[-1] + 2*std.iloc[-1]]
        }

        # 方法5：波动率通道
        atr = df['high'].rolling(14).max() - df['low'].rolling(14).min()
        methods['vol_channel'] = {
            'support': [current_price - atr.iloc[-1]],
            'resistance': [current_price + atr.iloc[-1]]
        }

        # 综合所有方法
        all_support = []
        all_resistance = []
        for method in methods.values():
            all_support += method['support']
            all_resistance += method['resistance']

        # 聚类分析
        return {
            'support': self._cluster_levels(all_support),
            'resistance': self._cluster_levels(all_resistance)
        }

    def analyze(self):
        """执行分析"""
        daily_result = self.calculate_support_resistance(self.daily_df)
        hourly_result = self.calculate_support_resistance(self.hourly_df)

        print("=== 日线级别 ===")
        print(f"支撑位：{sorted(daily_result['support'])}")
        print(f"压力位：{sorted(daily_result['resistance'], reverse=True)}")

        print("\n=== 小时级别 ===")
        print(f"支撑位：{sorted(hourly_result['support'])}")
        print(f"压力位：{sorted(hourly_result['resistance'], reverse=True)}")

if __name__ == "__main__":
    analyzer = HSTechAnalyzer()
    analyzer.analyze()
# Out:
# === 日线级别 ===
# 支撑位：[4441.91, 4954.92, 5600.0]
# 压力位：[6796.1, 5725.01, 5238.1]
#
# === 小时级别 ===
# 支撑位：[5418.62, 5487.26, 5600.0]
# 压力位：[5869.2, 5709.8, 5581.02]

# %% [markdown]
# 核心逻辑说明：
# 1. 多方法集成：综合运用移动平均线、布林带、斐波那契回撤、整数关口、近期高低点等五种技术分析方法
# 2. 动态参数配置：
# * 日线级别使用30天斐波那契窗口、20日滚动高低点、50日均线
# * 小时级别使用72小时(3天)斐波那契窗口、24小时滚动高低点、20小时均线
# 3. 智能过滤机制：
# * 自动过滤无效值（NaN）
# * 保留最接近当前价格的3个有效值
# * 自动处理整数关口的动态间隔（3000点以上使用50点间隔，以下使用25点）

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

def calculate_levels(df, current_price, period_type='day'):
    # 通用参数配置
    params = {
        'day': {'fib_window': 30, 'rolling_window': 20, 'ma_window': 50},
        'hour': {'fib_window': 72, 'rolling_window': 24, 'ma_window': 20}
    }[period_type]

    # 初始化存储字典
    levels = defaultdict(list)

    try:
        # 近期高低点
        levels['support'].append(df['low'].rolling(params['rolling_window']).min().iloc[-1])
        levels['resistance'].append(df['high'].rolling(params['rolling_window']).max().iloc[-1])

        # 斐波那契回撤
        fib_high = df['high'].iloc[-params['fib_window']:].max()
        fib_low = df['low'].iloc[-params['fib_window']:].min()
        fib_diff = fib_high - fib_low
        for ratio in [0.236, 0.382, 0.5, 0.618]:
            levels['support'].append(fib_high - fib_diff * ratio)
            levels['resistance'].append(fib_low + fib_diff * ratio)

        # 移动平均线
        ma = df['close'].rolling(params['ma_window']).mean().iloc[-1]
        levels['support' if current_price > ma else 'resistance'].append(ma)

        # 布林带
        std = df['close'].rolling(20).std().iloc[-1]
        levels['support'].append(ma - 2*std)
        levels['resistance'].append(ma + 2*std)

        # 整数关口
        base = 50 if current_price > 3000 else 25
        nearest_base = round(current_price / base) * base
        for offset in [-2, -1, 0, 1, 2]:
            levels['support' if (nearest_base + offset*base) < current_price else 'resistance'
                  ].append(nearest_base + offset*base)

    except Exception as e:
        print(f"Error in calculation: {str(e)}")

    return levels

def format_results(levels, current_price):
    # 结果过滤与排序
    def filter_sort(values):
        valid = [v for v in values if not np.isnan(v)]
        return sorted(set(round(v,2) for v in valid), key=lambda x: abs(x - current_price))[:3]

    return {
        '支撑位': filter_sort(levels['support']),
        '压力位': filter_sort(levels['resistance'])
    }

# 日线级别计算
df_day = pd.read_csv('hstech_data_1d.csv', parse_dates=['date']).sort_values('date')
day_levels = calculate_levels(df_day, df_day.iloc[-1]['close'], 'day')
day_result = format_results(day_levels, df_day.iloc[-1]['close'])

# 小时级别计算（使用5分钟数据聚合）
df_5min = pd.read_csv('hstech_data_5min.csv', parse_dates=['date'])
df_hour = df_5min.set_index('date').resample('h').agg({
    'open':'first', 'high':'max', 'low':'min', 'close':'last'}).dropna()
hour_levels = calculate_levels(df_hour, df_hour.iloc[-1]['close'], 'hour')
hour_result = format_results(hour_levels, df_hour.iloc[-1]['close'])

print("日线级别关键位：")
print(f"支撑位：{day_result['支撑位']}")
print(f"压力位：{day_result['压力位']}\n")

print("小时级别关键位：")
print(f"支撑位：{hour_result['支撑位']}")
print(f"压力位：{hour_result['压力位']}")
# Out:
# 日线级别关键位：
# 支撑位：[5650, 5600, 5550]
# 压力位：[5696.46, 5700, 5750]
#
# 小时级别关键位：
# 支撑位：[5650, 5600, 5587.96]
# 压力位：[5696.46, 5700, 5732.94]

# %%
from IPython import get_ipython # 导入 IPython 库，用于与 IPython 内核交互
from IPython.display import display # 导入 display 函数，用于在输出中显示内容

# %%
# !wget https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf # 下载 SimHei 字体文件
# !fc-list | grep simhei  # 验证字体是否安装成功并获取字体路径

import matplotlib.pyplot as plt # 导入 matplotlib.pyplot 库，用于绘图
import matplotlib.font_manager as fm # 导入 matplotlib.font_manager 库，用于管理字体
from datetime import date, datetime # 导入 date 和 datetime 类，用于处理日期和时间

# 更新 font_path 变量，根据 fc-list 命令的输出设置字体路径
font_path = 'SimHei.ttf'
fontprop = fm.FontProperties(fname=font_path, family='SimHei') # 创建 FontProperties 对象，指定字体文件和字体名称

# 刷新字体缓存
fm.fontManager.addfont(font_path)

# 将 SimHei 设置为整个图表的默认字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 用于正确显示负号

import numpy as np # 导入 numpy 库，用于数值计算
import pandas as pd # 导入 pandas 库，用于数据处理
from datetime import date # 导入 date 类，用于处理日期
from scipy import stats, signal # 导入 scipy 库中的 stats 和 signal 模块，用于统计分析和信号处理
from tqdm import tqdm # 导入 tqdm 库，用于显示进度条

class SupportPressureTester:
    def __init__(self, min15_path, min5_path, window_sizes=[20, 40, 60]):
        """
        初始化测试器

        参数：
            min15_path (str): 15分钟数据文件的路径。
            min5_path (str): 5分钟数据文件的路径。
            window_sizes (list): 回测窗口大小（以小时为单位）。
        """
        # 读取分时数据
        self.df_15min = pd.read_csv(min15_path)  # 读取15分钟数据
        self.df_5min = pd.read_csv(min5_path)  # 读取5分钟数据

        # 确保日期格式正确
        self.df_15min['date'] = pd.to_datetime(self.df_15min['date'])  # 将15分钟数据的日期列转换为日期时间格式
        self.df_5min['date'] = pd.to_datetime(self.df_5min['date'])  # 将5分钟数据的日期列转换为日期时间格式

        # 获取当前日期
        current_date = pd.Timestamp.today()  # 获取当前日期

        # 过滤未来数据
        self.df_15min = self.df_15min[self.df_15min['date'] <= current_date]  # 过滤15分钟数据中日期大于当前日期的数据
        self.df_5min = self.df_5min[self.df_5min['date'] <= current_date]  # 过滤5分钟数据中日期大于当前日期的数据

        # 按日期排序
        self.df_15min = self.df_15min.sort_values('date').reset_index(drop=True)  # 按日期对15分钟数据进行排序，并重置索引
        self.df_5min = self.df_5min.sort_values('date').reset_index(drop=True)  # 按日期对5分钟数据进行排序，并重置索引

        # 获取数据范围
        self.start_date = self.df_15min['date'].min()  # 获取数据的起始日期
        self.end_date = self.df_15min['date'].max()  # 获取数据的结束日期

        print(f"数据范围: {self.start_date.strftime('%Y-%m-%d %H:%M')} 至 {self.end_date.strftime('%Y-%m-%d %H:%M')}")  # 打印数据范围

        self.window_sizes = window_sizes  # 回测窗口大小（以小时为单位）
        self.results = []  # 初始化结果列表

    def calculate_levels(self, data_15min, data_5min):
        """
        计算支撑压力位

        参数：
            data_15min (pd.DataFrame): 15分钟训练数据。
            data_5min (pd.DataFrame): 5分钟训练数据。

        返回：
            dict: 包含支撑位、压力位和趋势信息的字典。
        """
        if len(data_15min) == 0 or len(data_5min) == 0:
            return {'支撑位': {}, '压力位': {}, '趋势': 'unknown'}  # 如果数据为空，返回空结果

        # 使用15分钟数据计算主要水平
        highs_15 = data_15min['high'].values  # 获取15分钟数据的最高价
        lows_15 = data_15min['low'].values  # 获取15分钟数据的最低价
        closes_15 = data_15min['close'].values  # 获取15分钟数据的收盘价
        volumes_15 = data_15min['volume'].values  # 获取15分钟数据的成交量
        current_price = closes_15[-1]  # 获取当前价格（最后一个收盘价）

        # 计算价格分布
        all_prices = np.concatenate([lows_15, highs_15, closes_15])  # 将最高价、最低价和收盘价合并
        kde = stats.gaussian_kde(all_prices)  # 使用高斯核密度估计计算价格分布
        price_range = np.linspace(min(all_prices), max(all_prices), 100)  # 创建价格范围
        density = kde(price_range)  # 计算价格范围内的密度

        # 寻找密集交易区域
        peaks, _ = signal.find_peaks(density, distance=10)  # 寻找密度峰值，作为潜在的支撑/压力位
        potential_levels = price_range[peaks]  # 获取潜在支撑/压力位的价格

        # 计算VWAP（成交量加权平均价）
        vwap_15 = np.average(closes_15, weights=volumes_15)  # 计算VWAP

        # 计算移动平均
        ma20_15 = np.mean(closes_15[-20:]) if len(closes_15) >= 20 else np.mean(closes_15)  # 计算20周期移动平均
        ma50_15 = np.mean(closes_15[-50:]) if len(closes_15) >= 50 else np.mean(closes_15)  # 计算50周期移动平均

        # 使用5分钟数据验证和细化
        closes_5 = data_5min['close'].values  # 获取5分钟数据的收盘价
        volumes_5 = data_5min['volume'].values  # 获取5分钟数据的成交量

        # 计算支撑位和压力位
        support_levels = {}  # 初始化支撑位字典
        resistance_levels = {}  # 初始化压力位字典

        # 添加基于价格分布的支撑位
        for level in potential_levels:
            if level < current_price:  # 如果潜在支撑位低于当前价格
                # 验证5分钟数据中的支撑情况
                near_level = (data_5min['low'] >= level * 0.998) & (data_5min['low'] <= level * 1.002)  # 寻找5分钟数据中接近潜在支撑位的价格
                if near_level.any():  # 如果存在接近潜在支撑位的价格
                    support_levels[f'支撑位_价格密集'] = level  # 将其添加到支撑位字典

        # 添加基于价格分布的压力位
        for level in potential_levels:
            if level > current_price:  # 如果潜在压力位高于当前价格
                # 验证5分钟数据中的压力情况
                near_level = (data_5min['high'] <= level * 1.002) & (data_5min['high'] >= level * 0.998)  # 寻找5分钟数据中接近潜在压力位的价格
                if near_level.any():  # 如果存在接近潜在压力位的价格
                    resistance_levels[f'压力位_价格密集'] = level  # 将其添加到压力位字典

        # 添加VWAP支撑压力
        if vwap_15 < current_price:  # 如果VWAP低于当前价格，则作为支撑位
            support_levels['支撑位_VWAP'] = vwap_15
        else:  # 否则作为压力位
            resistance_levels['压力位_VWAP'] = vwap_15

        # 添加移动平均支撑压力
        if ma20_15 < current_price:  # 如果20周期移动平均低于当前价格，则作为支撑位
            support_levels['支撑位_MA20'] = ma20_15
        else:  # 否则作为压力位
            resistance_levels['压力位_MA20'] = ma20_15

        if ma50_15 < current_price:  # 如果50周期移动平均低于当前价格，则作为支撑位
            support_levels['支撑位_MA50'] = ma50_15
        else:  # 否则作为压力位
            resistance_levels['压力位_MA50'] = ma50_15

        return {
            '支撑位': support_levels,  # 返回支撑位字典
            '压力位': resistance_levels,  # 返回压力位字典
            '趋势': 'up' if ma20_15 > ma50_15 else 'down'  # 根据移动平均判断趋势
        }

    def calculate_efficacy(self, levels, test_15min, test_5min):
        """
        计算支撑压力位有效性

        参数：
            levels (dict): 包含支撑位和压力位的字典。
            test_15min (pd.DataFrame): 15分钟测试数据。
            test_5min (pd.DataFrame): 5分钟测试数据。

        返回：
            dict: 包含支撑位和压力位有效性信息的字典。
        """
        efficacy = {'支撑位': {}, '压力位': {}}  # 初始化有效性字典

        if len(test_15min) < 3 or len(test_5min) < 3:  # 如果测试数据不足，返回空结果
            return efficacy

        def calculate_atr(df):
            """计算平均真实波动范围 (ATR)"""
            high = df['high']  # 获取最高价
            low = df['low']  # 获取最低价
            close = df['close']  # 获取收盘价
            tr1 = high - low  # 计算当日真实波动范围
            tr2 = abs(high - close.shift(1))  # 计算当日最高价与昨日收盘价之差的绝对值
            tr3 = abs(low - close.shift(1))  # 计算当日最低价与昨日收盘价之差的绝对值
            tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 取三者最大值作为当日真实波动范围
            return tr.mean()  # 返回平均真实波动范围

        # 计算动态阈值
        atr_15 = calculate_atr(test_15min)  # 计算15分钟数据的ATR
        atr_5 = calculate_atr(test_5min)  # 计算5分钟数据的ATR
        threshold_15 = min(max(atr_15 / test_15min['close'].mean(), 0.001), 0.005)  # 计算15分钟数据的阈值
        threshold_5 = min(max(atr_5 / test_5min['close'].mean(), 0.0005), 0.003)  # 计算5分钟数据的阈值

        for level_type in ['支撑位', '压力位']:  # 遍历支撑位和压力位
            level_dict = levels[level_type]  # 获取支撑位或压力位字典
            for key, level_price in level_dict.items():  # 遍历支撑位或压力位
                is_valid = False  # 初始化有效性标志

                if level_type == '支撑位':  # 如果是支撑位
                    # 15分钟验证
                    touched_15 = (test_15min['low'] <= level_price * (1 + threshold_15)).any()  # 检查15分钟数据中是否有价格触及支撑位
                    if touched_15:  # 如果触及支撑位
                        idx_15 = test_15min[test_15min['low'] <= level_price * (1 + threshold_15)].index[0]  # 获取触及支撑位的索引
                        post_touch_15 = test_15min.loc[idx_15:]  # 获取触及支撑位之后的数据

                        # 5分钟精确验证
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及支撑位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及支撑位之后的数据

                        if len(post_touch_5) > 0:  # 如果有触及支撑位之后的数据
                            bounce_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['low'].min()  # 计算反弹幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 检查是否有成交量激增
                            is_valid = bounce_5 > threshold_5 * 2 and volume_surge  # 判断支撑位是否有效

                else:  # 如果是压力位
                    # 15分钟验证
                    touched_15 = (test_15min['high'] >= level_price * (1 - threshold_15)).any()  # 检查15分钟数据中是否有价格触及压力位
                    if touched_15:  # 如果触及压力位
                        idx_15 = test_15min[test_15min['high'] >= level_price * (1 - threshold_15)].index[0]  # 获取触及压力位的索引
                        post_touch_15 = test_15min.loc[idx_15:]  # 获取触及压力位之后的数据

                        # 5分钟精确验证
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及压力位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及压力位之后的数据

                        if len(post_touch_5) > 0:  # 如果有触及压力位之后的数据
                            drop_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['high'].max()  # 计算下跌幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 检查是否有成交量激增
                            is_valid = drop_5 > threshold_5 * 2 and volume_surge  # 判断压力位是否有效

                efficacy[level_type][key] = is_valid  # 将支撑位或压力位的有效性信息添加到有效性字典

        return efficacy  # 返回有效性字典

    def run_backtest(self):
        """运行回测"""
        self.results = []  # 初始化结果列表

        for window_size in self.window_sizes:  # 遍历每个窗口大小
            print(f"\n正在测试 {window_size} 小时窗口...")
            window_results = []  # 初始化窗口结果列表

            # 将15分钟数据按小时分组
            hours = (self.df_15min['date'].max() - self.df_15min['date'].min()).total_seconds() / 3600  # 计算数据的时间跨度（以小时为单位）
            test_periods = int(hours - window_size)  # 计算测试周期数

            for i in tqdm(range(test_periods)):  # 遍历每个测试周期
                end_time = self.df_15min['date'].max() - pd.Timedelta(hours=i)  # 计算训练数据的结束时间
                start_time = end_time - pd.Timedelta(hours=window_size)  # 计算训练数据的起始时间
                test_start = end_time  # 计算测试数据的起始时间
                test_end = end_time + pd.Timedelta(hours=1)  # 计算测试数据的结束时间

                # 获取训练数据
                train_15min = self.df_15min[(self.df_15min['date'] >= start_time) &
                                          (self.df_15min['date'] < end_time)]  # 获取15分钟训练数据
                train_5min = self.df_5min[(self.df_5min['date'] >= start_time) &
                                        (self.df_5min['date'] < end_time)]  # 获取5分钟训练数据

                # 获取测试数据
                test_15min = self.df_15min[(self.df_15min['date'] >= test_start) &
                                         (self.df_15min['date'] < test_end)]  # 获取15分钟测试数据
                test_5min = self.df_5min[(self.df_5min['date'] >= test_start) &
                                       (self.df_5min['date'] < test_end)]  # 获取5分钟测试数据

                if len(train_15min) == 0 or len(test_15min) == 0:  # 如果训练数据或测试数据为空，跳过本次循环
                    continue

                # 计算支撑压力位
                levels = self.calculate_levels(train_15min, train_5min)  # 计算支撑压力位

                # 验证支撑压力位有效性
                efficacy = self.calculate_efficacy(levels, test_15min, test_5min)  # 计算支撑压力位有效性

                window_results.append({  # 将结果添加到窗口结果列表
                    '训练开始': start_time,  # 训练数据的起始时间
                    '训练结束': end_time,  # 训练数据的结束时间
                    '测试时间': test_start,  # 测试数据的起始时间
                    '支撑压力位': levels,  # 支撑压力位
                    '验证结果': efficacy  # 支撑压力位有效性
                })

            self.results.append({  # 将窗口结果添加到结果列表
                '窗口大小': window_size,  # 窗口大小
                '结果': window_results  # 窗口结果列表
            })

            # 分析该窗口大小的整体表现
            self.analyze_window_performance(window_results)  # 分析窗口表现

    def analyze_window_performance(self, results):
        """
        分析窗口表现

        参数：
            results (list): 窗口结果列表。
        """
        total_support = 0  # 初始化支撑位总数
        valid_support = 0  # 初始化有效支撑位数
        total_resistance = 0  # 初始化压力位总数
        valid_resistance = 0  # 初始化有效压力位数

        for result in results:  # 遍历每个结果
            efficacy = result['验证结果']  # 获取支撑压力位有效性信息

            for key, valid in efficacy['支撑位'].items():  # 遍历支撑位
                total_support += 1  # 累加支撑位总数
                if valid:  # 如果支撑位有效
                    valid_support += 1  # 累加有效支撑位数

            for key, valid in efficacy['压力位'].items():  # 遍历压力位
                total_resistance += 1  # 累加压力位总数
                if valid:  # 如果压力位有效
                    valid_resistance += 1  # 累加有效压力位数

        print("\n窗口表现分析:")
        print(f"总体样本数: {len(results)}")  # 打印样本总数
        print(f"支撑位准确率: {valid_support/total_support*100:.2f}% (样本数: {total_support})" if total_support > 0 else "支撑位样本不足")  # 打印支撑位准确率
        print(f"压力位准确率: {valid_resistance/total_resistance*100:.2f}% (样本数: {total_resistance})" if total_resistance > 0 else "压力位样本不足")  # 打印压力位准确率

    def plot_results(self):
        """绘制支撑压力位和价格走势"""
        import matplotlib.pyplot as plt
        from matplotlib.gridspec import GridSpec

        # 获取最近24小时的数据用于绘图
        last_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]

        # 创建图表
        fig = plt.figure(figsize=(15, 10))
        gs = GridSpec(2, 1, height_ratios=[3, 1])

        # 价格走势和支撑压力位
        ax1 = fig.add_subplot(gs[0])
        ax2 = fig.add_subplot(gs[1])

        # 绘制价格走势
        ax1.plot(last_24h['date'], last_24h['close'], label='价格', color='black', alpha=0.7)

        # 获取最新的支撑压力位
        latest_levels = self.calculate_levels(
            last_24h,
            self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]
        )

        # 绘制支撑位
        for key, level in latest_levels['支撑位'].items():
            ax1.axhline(y=level, color='g', linestyle='--', alpha=0.5, label=f'{key}: {level:.2f}')

        # 绘制压力位
        for key, level in latest_levels['压力位'].items():
            ax1.axhline(y=level, color='r', linestyle='--', alpha=0.5, label=f'{key}: {level:.2f}')

        # 绘制成交量
        ax2.bar(last_24h['date'], last_24h['volume'], color='blue', alpha=0.3)

        # 设置图表格式
        ax1.set_title('价格走势与支撑压力位 (最近24小时)')
        ax1.set_xlabel('时间')
        ax1.set_ylabel('价格')
        ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax1.grid(True, alpha=0.3)

        ax2.set_title('成交量')
        ax2.set_xlabel('时间')
        ax2.set_ylabel('成交量')
        ax2.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()

    def print_latest_result(self):
        """打印最新的支撑压力位预测结果"""
        # 获取最近数据
        latest_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]
        latest_24h_5min = self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]

        # 计算最新的支撑压力位
        latest_levels = self.calculate_levels(latest_24h, latest_24h_5min)
        current_price = latest_24h['close'].iloc[-1]

        print("\n=== 最新预测结果 ===")
        print(f"当前价格: {current_price:.2f}")
        print(f"市场趋势: {latest_levels['趋势']}")
        print("\n支撑位:")
        for key, level in latest_levels['支撑位'].items():
            distance = (current_price - level) / current_price * 100
            print(f"{key}: {level:.2f} (距当前价格: {distance:.2f}%)")

        print("\n压力位:")
        for key, level in latest_levels['压力位'].items():
            distance = (level - current_price) / current_price * 100
            print(f"{key}: {level:.2f} (距当前价格: {distance:.2f}%)")

        # 打印准确率统计
        print("\n=== 准确率统计 ===")
        for result in self.results:
            window_size = result['窗口大小']
            window_results = result['结果']

            total_support = sum(len(r['验证结果']['支撑位']) for r in window_results)
            valid_support = sum(sum(v for v in r['验证结果']['支撑位'].values()) for r in window_results)

            total_resistance = sum(len(r['验证结果']['压力位']) for r in window_results)
            valid_resistance = sum(sum(v for v in r['验证结果']['压力位'].values()) for r in window_results)

            print(f"\n{window_size}小时窗口:")
            print(f"支撑位准确率: {valid_support/total_support*100:.2f}% (样本数: {total_support})")
            print(f"压力位准确率: {valid_resistance/total_resistance*100:.2f}% (样本数: {total_resistance})")




tester = SupportPressureTester(
    min15_path='hstech_data_15min.csv',
    min5_path='hstech_data_5min.csv',
    window_sizes=[24, 48, 72]  # 使用小时作为窗口单位
)
tester.run_backtest()
tester.plot_results()
tester.print_latest_result()
# Out:
# --2025-02-20 15:57:31--  https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9751960 (9.3M) [application/octet-stream]
# Saving to: ‘SimHei.ttf.8’
#
# SimHei.ttf.8        100%[===================>]   9.30M  --.-KB/s    in 0.05s
#
# 2025-02-20 15:57:31 (197 MB/s) - ‘SimHei.ttf.8’ saved [9751960/9751960]
#
# 数据范围: 2025-01-20 09:45 至 2025-02-19 16:00
#
# 正在测试 24 小时窗口...
# 100%|██████████| 702/702 [00:04<00:00, 153.59it/s]
# 窗口表现分析:
# 总体样本数: 146
# 支撑位准确率: 46.69% (样本数: 242)
# 压力位准确率: 64.47% (样本数: 152)
#
# 正在测试 48 小时窗口...
# 100%|██████████| 678/678 [00:09<00:00, 72.78it/s]
# 窗口表现分析:
# 总体样本数: 138
# 支撑位准确率: 40.57% (样本数: 244)
# 压力位准确率: 63.16% (样本数: 133)
#
# 正在测试 72 小时窗口...
# ...

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !wget https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf # 下载 SimHei 字体文件

import numpy as np  # 导入numpy库，用于数值计算
import pandas as pd  # 导入pandas库，用于数据处理
from datetime import date  # 导入date模块，用于处理日期
from scipy import stats, signal  # 导入scipy库中的stats和signal模块，用于统计分析和信号处理
from tqdm import tqdm  # 导入tqdm库，用于显示进度条

import matplotlib.pyplot as plt  # 导入matplotlib库，用于绘图
import matplotlib.font_manager as fm  # 导入font_manager模块，用于管理字体
from datetime import date, datetime  # 导入date和datetime模块，用于处理日期和时间


# 设置中文字体
font_path = 'SimHei.ttf'  # 设置字体路径，请确保SimHei.ttf字体文件在您的环境中可用
fontprop = fm.FontProperties(fname=font_path, family='SimHei')  # 创建字体属性对象

# 刷新字体缓存
fm.fontManager.addfont(font_path)  # 将字体添加到字体管理器

# 设置SimHei为默认字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置全局字体为SimHei
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题


class SupportPressureTester:
    def __init__(self, min15_path, min5_path, window_sizes=[24, 48, 72]):
        """初始化测试器"""
        # 读取分时数据
        self.df_15min = pd.read_csv(min15_path)  # 读取15分钟数据
        self.df_5min = pd.read_csv(min5_path)  # 读取5分钟数据

        # 确保日期格式正确
        self.df_15min['date'] = pd.to_datetime(self.df_15min['date'])  # 将日期列转换为datetime格式
        self.df_5min['date'] = pd.to_datetime(self.df_5min['date'])  # 将日期列转换为datetime格式

        # 按日期排序
        self.df_15min = self.df_15min.sort_values('date').reset_index(drop=True)  # 按日期排序并重置索引
        self.df_5min = self.df_5min.sort_values('date').reset_index(drop=True)  # 按日期排序并重置索引

        self.window_sizes = window_sizes  # 设置窗口大小
        self.results = []  # 初始化结果列表

        print(f"数据范围: {self.df_15min['date'].min().strftime('%Y-%m-%d %H:%M')} 至 {self.df_15min['date'].max().strftime('%Y-%m-%d %H:%M')}")

    def calculate_psychological_levels(self, current_price, range_percent=0.05):
        """计算心理关口位"""
        levels = {}  # 初始化关口位字典

        # 确定价格范围
        price_range_low = current_price * (1 - range_percent)  # 计算价格范围下限
        price_range_high = current_price * (1 + range_percent)  # 计算价格范围上限

        # 生成可能的心理关口
        thousands = [i * 1000 for i in range(int(price_range_low/1000), int(price_range_high/1000) + 1)]  # 生成整千位关口
        hundreds = [i * 100 for i in range(int(price_range_low/100), int(price_range_high/100) + 1)]  # 生成整百位关口
        fifties = [i * 50 for i in range(int(price_range_low/50), int(price_range_high/50) + 1)]  # 生成半位关口
        special = [5000, 5500, 6000, 6500, 7000]  # 特殊关口

        all_levels = {
            '整千位': thousands,
            '整百位': hundreds,
            '半位': fifties,
            '特殊关口': special
        }  # 将所有关口类型和对应的关口值存储在字典中


        for level_type, numbers in all_levels.items():  # 遍历所有关口类型
            for number in numbers:  # 遍历该类型下的所有关口值
                if price_range_low <= number <= price_range_high:  # 如果关口值在价格范围内
                    if number < current_price:  # 如果关口值小于当前价格，则为支撑位
                        levels[f'支撑位_心理_{level_type}_{number}'] = number
                    elif number > current_price:  # 如果关口值大于当前价格，则为压力位
                        levels[f'压力位_心理_{level_type}_{number}'] = number

        return levels  # 返回关口位字典

    def calculate_fibonacci_projections(self, data, is_breakout_high=True):
        """计算斐波那契投射位"""
        high = data['high'].max()  # 获取最高价
        low = data['low'].min()  # 获取最低价
        diff = high - low  # 计算价差

        if is_breakout_high:  # 如果突破高点
            return {
                '压力位_Fib_1.272': high + diff * 0.272,  # 计算1.272倍斐波那契压力位
                '压力位_Fib_1.414': high + diff * 0.414,  # 计算1.414倍斐波那契压力位
                '压力位_Fib_1.618': high + diff * 0.618   # 计算1.618倍斐波那契压力位
            }
        else:  # 如果突破低点
            return {
                '支撑位_Fib_0.786': low - diff * 0.214,  # 计算0.786倍斐波那契支撑位
                '支撑位_Fib_0.618': low - diff * 0.382,  # 计算0.618倍斐波那契支撑位
                '支撑位_Fib_0.5': low - diff * 0.5      # 计算0.5倍斐波那契支撑位
            }

    def calculate_volatility_based_levels(self, data, is_breakout_high=True):
        """基于波动率计算潜在位置"""
        high = data['high']  # 获取最高价序列
        low = data['low']  # 获取最低价序列
        close = data['close'].shift(1)  # 获取前一周期收盘价序列
        tr1 = high - low  # 计算当日最高价与最低价之差
        tr2 = abs(high - close)  # 计算当日最高价与前一周期收盘价之差的绝对值
        tr3 = abs(low - close)  # 计算当日最低价与前一周期收盘价之差的绝对值
        tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 计算真实波动幅度TR
        atr = tr.rolling(window=14).mean().iloc[-1]  # 计算平均真实波动幅度ATR

        current_price = data['close'].iloc[-1]  # 获取当前价格

        if is_breakout_high:  # 如果突破高点
            return {
                '压力位_ATR_1': current_price + atr,  # 计算基于ATR的压力位1
                '压力位_ATR_2': current_price + atr * 2,  # 计算基于ATR的压力位2
                '压力位_ATR_3': current_price + atr * 3   # 计算基于ATR的压力位3
            }
        else:  # 如果突破低点
            return {
                '支撑位_ATR_1': current_price - atr,  # 计算基于ATR的支撑位1
                '支撑位_ATR_2': current_price - atr * 2,  # 计算基于ATR的支撑位2
                '支撑位_ATR_3': current_price - atr * 3   # 计算基于ATR的支撑位3
            }


    def calculate_traditional_levels(self, data_15min, data_5min):
        """计算传统支撑压力位"""
        if len(data_15min) == 0 or len(data_5min) == 0:  # 如果数据为空，则返回空字典
            return {'支撑位': {}, '压力位': {}, '趋势': 'unknown'}

        # 使用15分钟数据计算
        highs = data_15min['high'].values  # 获取最高价序列
        lows = data_15min['low'].values  # 获取最低价序列
        closes = data_15min['close'].values  # 获取收盘价序列
        volumes = data_15min['volume'].values  # 获取成交量序列
        current_price = closes[-1]  # 获取当前价格

        # 计算VWAP
        vwap = np.average(closes, weights=volumes)  # 计算成交量加权平均价

        # 计算移动平均
        ma20 = np.mean(closes[-20:]) if len(closes) >= 20 else np.mean(closes)  # 计算20周期移动平均线
        ma50 = np.mean(closes[-50:]) if len(closes) >= 50 else np.mean(closes)  # 计算50周期移动平均线

        levels = {'支撑位': {}, '压力位': {}, '趋势': 'up' if ma20 > ma50 else 'down'}  # 初始化关口位字典，并根据移动平均线判断趋势

        # 分配VWAP和MA
        if vwap < current_price:  # 如果VWAP小于当前价格，则为支撑位
            levels['支撑位']['支撑位_VWAP'] = vwap
        else:  # 否则为压力位
            levels['压力位']['压力位_VWAP'] = vwap

        if ma20 < current_price:  # 如果MA20小于当前价格，则为支撑位
            levels['支撑位']['支撑位_MA20'] = ma20
        else:  # 否则为压力位
            levels['压力位']['压力位_MA20'] = ma20

        if ma50 < current_price:  # 如果MA50小于当前价格，则为支撑位
            levels['支撑位']['支撑位_MA50'] = ma50
        else:  # 否则为压力位
            levels['压力位']['压力位_MA50'] = ma50

        return levels  # 返回关口位字典


    def calculate_levels(self, data_15min, data_5min):
        """计算所有支撑压力位"""
        # 首先计算传统支撑压力位
        levels = self.calculate_traditional_levels(data_15min, data_5min)  # 计算传统关口位
        current_price = data_15min['close'].iloc[-1]  # 获取当前价格

        # 检查是否突破新高或新低
        is_breakout_high = current_price >= data_15min['high'].max()  # 判断是否突破新高
        is_breakout_low = current_price <= data_15min['low'].min()  # 判断是否突破新低

        # 添加心理关口
        psychological_levels = self.calculate_psychological_levels(current_price)  # 计算心理关口位
        for key, value in psychological_levels.items():  # 遍历心理关口位
            if '支撑位' in key:  # 如果是支撑位
                levels['支撑位'][key] = value
            else:  # 如果是压力位
                levels['压力位'][key] = value

        if is_breakout_high:  # 如果突破新高
            # 添加突破高点时的额外压力位
            levels['压力位'].update(self.calculate_fibonacci_projections(data_15min, True))  # 添加斐波那契投射压力位
            levels['压力位'].update(self.calculate_volatility_based_levels(data_15min, True))  # 添加基于波动率的压力位

        if is_breakout_low:  # 如果突破新低
            # 添加突破低点时的额外支撑位
            levels['支撑位'].update(self.calculate_fibonacci_projections(data_15min, False))  # 添加斐波那契投射支撑位
            levels['支撑位'].update(self.calculate_volatility_based_levels(data_15min, False))  # 添加基于波动率的支撑位

        # 过滤太接近的位置
        def filter_levels(levels_dict):  # 定义过滤函数
            sorted_levels = dict(sorted(levels_dict.items(), key=lambda x: x[1]))  # 按关口值排序
            filtered_levels = {}  # 初始化过滤后的关口位字典
            last_level = None  # 初始化上一个关口位
            min_distance = current_price * 0.002  # 设置最小距离阈值

            for key, value in sorted_levels.items():  # 遍历排序后的关口位
                if last_level is None or abs(value - last_level) >= min_distance:  # 如果当前关口位与上一个关口位的距离大于阈值
                    filtered_levels[key] = value  # 将当前关口位添加到过滤后的字典中
                    last_level = value  # 更新上一个关口位

            return filtered_levels  # 返回过滤后的关口位字典

        levels['支撑位'] = filter_levels(levels['支撑位'])  # 过滤支撑位
        levels['压力位'] = filter_levels(levels['压力位'])  # 过滤压力位

        return levels  # 返回所有关口位


    def filter_levels(levels_dict):
        """过滤太接近的支撑/压力位"""
        sorted_levels = dict(sorted(levels_dict.items(), key=lambda x: x[1]))  # 对支撑/压力位按值排序
        filtered_levels = {}  # 初始化过滤后的字典
        last_level = None  # 初始化上一个支撑/压力位
        # 增加最小距离阈值
        min_distance = current_price * 0.005  # 设置最小距离阈值，防止支撑/压力位过于接近

        for key, value in sorted_levels.items():  # 遍历排序后的支撑/压力位
            if last_level is None or abs(value - last_level) >= min_distance:  # 如果当前支撑/压力位与上一个支撑/压力位的距离大于阈值
                filtered_levels[key] = value  # 将当前支撑/压力位添加到过滤后的字典中
                last_level = value  # 更新上一个支撑/压力位

        return filtered_levels  # 返回过滤后的字典


    def calculate_efficacy(self, levels, test_15min, test_5min):
        """计算支撑压力位有效性"""
        efficacy = {'支撑位': {}, '压力位': {}}  # 初始化有效性字典

        if len(test_15min) < 3 or len(test_5min) < 3:  # 如果测试数据不足，则返回空字典
            return efficacy

        def calculate_atr(df):  # 定义计算ATR的函数
            high = df['high']  # 获取最高价序列
            low = df['low']  # 获取最低价序列
            close = df['close']  # 获取收盘价序列
            tr1 = high - low  # 计算当日最高价与最低价之差
            tr2 = abs(high - close.shift(1))  # 计算当日最高价与前一周期收盘价之差的绝对值
            tr3 = abs(low - close.shift(1))  # 计算当日最低价与前一周期收盘价之差的绝对值
            tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 计算真实波动幅度TR
            return tr.mean()  # 返回平均真实波动幅度ATR

        atr_15 = calculate_atr(test_15min)  # 计算15分钟数据的ATR
        atr_5 = calculate_atr(test_5min)  # 计算5分钟数据的ATR
        threshold_15 = min(max(atr_15 / test_15min['close'].mean(), 0.001), 0.005)  # 计算15分钟数据的阈值
        threshold_5 = min(max(atr_5 / test_5min['close'].mean(), 0.0005), 0.003)  # 计算5分钟数据的阈值


        for level_type in ['支撑位', '压力位']:  # 遍历支撑位和压力位
            level_dict = levels[level_type]  # 获取当前类型的关口位字典
            for key, level_price in level_dict.items():  # 遍历关口位
                is_valid = False  # 初始化有效性标志

                if level_type == '支撑位':  # 如果是支撑位
                    touched_15 = (test_15min['low'] <= level_price * (1 + threshold_15)).any()  # 判断15分钟数据是否触及支撑位
                    if touched_15:  # 如果触及支撑位
                        idx_15 = test_15min[test_15min['low'] <= level_price * (1 + threshold_15)].index[0]  # 获取触及支撑位的索引
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及支撑位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及支撑位之后的数据
                        if len(post_touch_5) > 0:  # 如果有触及支撑位之后的数据

                            bounce_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['low'].min()  # 计算反弹幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 判断是否有成交量异动
                            is_valid = bounce_5 > threshold_5 * 2 and volume_surge  # 判断支撑位是否有效

                else:  # 如果是压力位
                    touched_15 = (test_15min['high'] >= level_price * (1 - threshold_15)).any()  # 判断15分钟数据是否触及压力位
                    if touched_15:  # 如果触及压力位
                        idx_15 = test_15min[test_15min['high'] >= level_price * (1 - threshold_15)].index[0]  # 获取触及压力位的索引
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及压力位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及压力位之后的数据
                        if len(post_touch_5) > 0:  # 如果有触及压力位之后的数据
                            drop_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['high'].max()  # 计算下跌幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 判断是否有成交量异动
                            is_valid = drop_5 > threshold_5 * 2 and volume_surge  # 判断压力位是否有效


                efficacy[level_type][key] = is_valid  # 将有效性标志存储到字典中


        return efficacy  # 返回有效性字典

    def run_backtest(self):
        """运行回测"""
        self.results = []  # 初始化结果列表

        for window_size in self.window_sizes:  # 遍历窗口大小
            print(f"\n正在测试 {window_size} 小时窗口...")
            window_results = []  # 初始化窗口结果列表

            hours = (self.df_15min['date'].max() - self.df_15min['date'].min()).total_seconds() / 3600  # 计算总小时数
            test_periods = int(hours - window_size)  # 计算测试周期数


            for i in tqdm(range(test_periods)):  # 遍历测试周期，使用tqdm显示进度条
                end_time = self.df_15min['date'].max() - pd.Timedelta(hours=i)  # 计算训练结束时间
                start_time = end_time - pd.Timedelta(hours=window_size)  # 计算训练开始时间
                test_start = end_time  # 计算测试开始时间
                test_end = end_time + pd.Timedelta(hours=1)  # 计算测试结束时间

                # 获取训练数据
                train_15min = self.df_15min[(self.df_15min['date'] >= start_time) &
                                          (self.df_15min['date'] < end_time)]  # 获取15分钟训练数据
                train_5min = self.df_5min[(self.df_5min['date'] >= start_time) &
                                        (self.df_5min['date'] < end_time)]  # 获取5分钟训练数据

                # 获取测试数据
                test_15min = self.df_15min[(self.df_15min['date'] >= test_start) &
                                         (self.df_15min['date'] < test_end)]  # 获取15分钟测试数据
                test_5min = self.df_5min[(self.df_5min['date'] >= test_start) &
                                       (self.df_5min['date'] < test_end)]  # 获取5分钟测试数据

                if len(train_15min) == 0 or len(test_15min) == 0:  # 如果训练数据或测试数据为空，则跳过
                    continue

                levels = self.calculate_levels(train_15min, train_5min)  # 计算支撑压力位
                efficacy = self.calculate_efficacy(levels, test_15min, test_5min)  # 计算支撑压力位有效性

                window_results.append({  # 将结果添加到窗口结果列表中
                    '训练开始': start_time,
                    '训练结束': end_time,
                    '测试时间': test_start,
                    '支撑压力位': levels,
                    '验证结果': efficacy
                })

            self.results.append({  # 将窗口结果添加到总结果列表中
                '窗口大小': window_size,
                '结果': window_results
            })

            self.analyze_window_performance(window_results)  # 分析窗口表现


    def analyze_window_performance(self, results):
        """分析窗口表现"""
        total_support = 0  # 初始化支撑位总数
        valid_support = 0  # 初始化有效支撑位数
        total_resistance = 0  # 初始化压力位总数
        valid_resistance = 0  # 初始化有效压力位数

        for result in results:  # 遍历结果
            efficacy = result['验证结果']  # 获取有效性字典

            for key, valid in efficacy['支撑位'].items():  # 遍历支撑位
                total_support += 1  # 累加支撑位总数
                if valid:  # 如果支撑位有效
                    valid_support += 1  # 累加有效支撑位数

            for key, valid in efficacy['压力位'].items():  # 遍历压力位
                total_resistance += 1  # 累加压力位总数
                if valid:  # 如果压力位有效
                    valid_resistance += 1  # 累加有效压力位数

        print("\n窗口表现分析:")
        print(f"总体样本数: {len(results)}")  # 打印样本总数
        if total_support > 0:  # 如果有支撑位
            print(f"支撑位准确率: {valid_support/total_support*100:.2f}% (样本数: {total_support})")  # 打印支撑位准确率
        if total_resistance > 0:  # 如果有压力位
            print(f"压力位准确率: {valid_resistance/total_resistance*100:.2f}% (样本数: {total_resistance})")  # 打印压力位准确率


    def print_latest_result(self):
        """打印最新的支撑压力位预测结果"""
        latest_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近24小时的15分钟数据
        latest_24h_5min = self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近24小时的5分钟数据

        latest_levels = self.calculate_levels(latest_24h, latest_24h_5min)  # 计算最新的支撑压力位
        current_price = latest_24h['close'].iloc[-1]  # 获取当前价格

        print("\n=== 最新预测结果 ===")
        print(f"当前价格: {current_price:.2f}")  # 打印当前价格
        print(f"市场趋势: {latest_levels['趋势']}")  # 打印市场趋势

        def print_levels(levels, level_type):  # 定义打印支撑/压力位的函数
            if levels:  # 如果有支撑/压力位
                print(f"\n{level_type}:")  # 打印支撑/压力位类型
                sorted_levels = sorted(levels.items(),
                                     key=lambda x: abs(x[1] - current_price))  # 按距离当前价格排序

                for key, level in sorted_levels:  # 遍历支撑/压力位
                    if level_type == "支撑位":  # 如果是支撑位
                        distance = (current_price - level) / current_price * 100  # 计算距离当前价格的百分比
                    else:  # 如果是压力位
                        distance = (level - current_price) / current_price * 100  # 计算距离当前价格的百分比

                    strength = "强" if "心理" in key or "VWAP" in key else "中"  # 根据类型判断强度
                    if distance < 0.5:  # 如果距离当前价格很近
                        strength += "+"  # 增加强度

                    print(f"{key}: {level:.2f} (距当前价格: {distance:.2f}%, 强度: {strength})")  # 打印支撑/压力位信息

        print_levels(latest_levels['支撑位'], "支撑位")  # 打印支撑位
        print_levels(latest_levels['压力位'], "压力位")  # 打印压力位


    def plot_results(self):
        """绘制支撑压力位和价格走势"""
        import matplotlib.pyplot as plt  # 导入matplotlib库
        from matplotlib.gridspec import GridSpec  # 导入GridSpec用于创建子图
        import matplotlib.dates as mdates  # 导入mdates用于处理日期格式
        from matplotlib.patches import Rectangle  # 导入Rectangle用于绘制矩形

        # 获取最近24小时的数据用于绘图
        last_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近24小时的15分钟数据

        # 创建图表
        #plt.style.use('classic')
        fig = plt.figure(figsize=(15, 10))  # 创建图表对象，设置尺寸
        gs = GridSpec(2, 1, height_ratios=[3, 1])  # 创建GridSpec对象，用于划分图表区域

        # 设置背景色
        fig.patch.set_facecolor('#F0F3F5')  # 设置图表背景色

        # 价格走势和支撑压力位
        ax1 = fig.add_subplot(gs[0])  # 创建第一个子图，用于绘制价格走势和支撑压力位
        ax2 = fig.add_subplot(gs[1])  # 创建第二个子图，用于绘制成交量

        # 设置子图背景色
        ax1.set_facecolor('#FFFFFF')  # 设置第一个子图背景色
        ax2.set_facecolor('#FFFFFF')  # 设置第二个子图背景色

        # 添加网格
        ax1.grid(True, linestyle='--', alpha=0.3)  # 为第一个子图添加网格
        ax2.grid(True, linestyle='--', alpha=0.3)  # 为第二个子图添加网格

        # 绘制K线图
        ax1.plot(last_24h['date'], last_24h['close'],
                color='#2C3E50', linewidth=1.5, label='收盘价',
                zorder=5)  # 绘制收盘价曲线

        # 绘制价格区间
        ax1.fill_between(last_24h['date'], last_24h['high'], last_24h['low'],
                        color='#BDC3C7', alpha=0.3, label='价格区间',
                        zorder=4)  # 绘制价格区间

        # 获取最新的支撑压力位
        latest_levels = self.calculate_levels(
            last_24h,
            self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]
        )  # 计算最新的支撑压力位

        # 定义支撑位和压力位的颜色
        support_colors = ['#27AE60', '#2ECC71', '#82E0AA']  # 深到浅的绿色
        resistance_colors = ['#C0392B', '#E74C3C', '#F1948A']  # 深到浅的红色

        # 绘制支撑位
        for i, (key, level) in enumerate(latest_levels['支撑位'].items()):  # 遍历支撑位
            color = support_colors[min(i, len(support_colors)-1)]  # 选择颜色
            style = '-' if '心理' in key else '--'  # 选择线条样式
            ax1.axhline(y=level, color=color, linestyle=style, alpha=0.7,
                        label=f'{key}: {level:.2f}',
                        zorder=3)  # 绘制支撑位水平线

        # 绘制压力位
        for i, (key, level) in enumerate(latest_levels['压力位'].items()):  # 遍历压力位
            color = resistance_colors[min(i, len(resistance_colors)-1)]  # 选择颜色
            style = '-' if '心理' in key else '--'  # 选择线条样式
            ax1.axhline(y=level, color=color, linestyle=style, alpha=0.7,
                        label=f'{key}: {level:.2f}',
                        zorder=3)  # 绘制压力位水平线


        # 绘制成交量柱状图
        for i in range(len(last_24h)):  # 遍历数据
            if i > 0:  # 如果不是第一个数据
                color = '#2ECC71' if last_24h['close'].iloc[i] >= last_24h['close'].iloc[i-1] else '#E74C3C'  # 根据收盘价变化选择颜色
            else:  # 如果是第一个数据
                color = '#2ECC71'  # 默认颜色

            ax2.bar(last_24h['date'].iloc[i], last_24h['volume'].iloc[i],
                    width=pd.Timedelta(minutes=10),  # 调整柱子宽度
                    color=color, alpha=0.7)  # 绘制成交量柱状图


        # 设置时间格式
        date_formatter = mdates.DateFormatter('%H:%M')  # 创建日期格式化器
        ax1.xaxis.set_major_formatter(date_formatter)  # 设置第一个子图的x轴日期格式
        ax2.xaxis.set_major_formatter(date_formatter)  # 设置第二个子图的x轴日期格式

        # 设置标题和标签
        ax1.set_title('价格走势与支撑压力位 (最近24小时)', fontsize=14, pad=20)  # 设置第一个子图的标题
        ax1.set_xlabel('时间', fontsize=12)  # 设置第一个子图的x轴标签
        ax1.set_ylabel('价格', fontsize=12)  # 设置第一个子图的y轴标签

        ax2.set_title('成交量', fontsize=14, pad=20)  # 设置第二个子图的标题
        ax2.set_xlabel('时间', fontsize=12)  # 设置第二个子图的x轴标签
        ax2.set_ylabel('成交量', fontsize=12)  # 设置第二个子图的y轴标签

        # 优化刻度标签
        for ax in [ax1, ax2]:  # 遍历子图
            ax.tick_params(axis='both', labelsize=10)  # 设置刻度标签大小
            plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')  # 旋转x轴刻度标签

        # 优化图例位置和样式
        ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10,
                  facecolor='white', edgecolor='none', framealpha=0.8)  # 设置图例样式

        # 添加图表说明
        current_price = last_24h['close'].iloc[-1]  # 获取当前价格
        trend = latest_levels.get('趋势', 'unknown')  # 获取市场趋势
        trend_text = '上涨' if trend == 'up' else '下跌' if trend == 'down' else '未知'  # 转换市场趋势为中文

        # 使用文本框添加说明
        textstr = f'当前价格: {current_price:.2f}\n市场趋势: {trend_text}'  # 创建说明文本
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)  # 设置文本框样式
        ax1.text(0.02, 0.98, textstr, transform=ax1.transAxes,
                fontsize=12, verticalalignment='top',
                bbox=props)  # 添加文本框到图表

        plt.tight_layout()  # 调整图表布局
        plt.show()  # 显示图表


tester = SupportPressureTester(
    min15_path='hstech_data_15min.csv',  # 设置15分钟数据文件路径
    min5_path='hstech_data_5min.csv',  # 设置5分钟数据文件路径
    window_sizes=[24, 48, 72]  # 使用小时作为窗口单位
)
tester.run_backtest()  # 运行回测
tester.plot_results()  # 绘制结果
tester.print_latest_result()  # 打印最新预测结果
# Out:
# --2025-02-20 15:57:56--  https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9751960 (9.3M) [application/octet-stream]
# Saving to: ‘SimHei.ttf.9’
#
# SimHei.ttf.9        100%[===================>]   9.30M  --.-KB/s    in 0.07s
#
# 2025-02-20 15:57:56 (124 MB/s) - ‘SimHei.ttf.9’ saved [9751960/9751960]
#
# 数据范围: 2025-01-20 09:45 至 2025-02-19 16:00
#
# 正在测试 24 小时窗口...
# 100%|██████████| 702/702 [00:07<00:00, 96.73it/s]
# 窗口表现分析:
# 总体样本数: 146
# 支撑位准确率: 20.82% (样本数: 538)
# 压力位准确率: 21.58% (样本数: 519)
#
# 正在测试 48 小时窗口...
# 100%|██████████| 678/678 [00:06<00:00, 105.69it/s]
# 窗口表现分析:
# 总体样本数: 138
# 支撑位准确率: 21.63% (样本数: 541)
# 压力位准确率: 21.54% (样本数: 492)
#
# 正在测试 72 小时窗口...
# ...

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !wget https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf # 下载 SimHei 字体文件

import numpy as np  # 导入 NumPy 库，用于数值计算
import pandas as pd  # 导入 Pandas 库，用于数据处理
from datetime import date  # 导入日期时间模块
from scipy import stats, signal  # 导入 SciPy 库，用于科学计算
from tqdm import tqdm  # 导入 tqdm 库，用于显示进度条

import matplotlib.pyplot as plt  # 导入 Matplotlib 库，用于绘图
import matplotlib.font_manager as fm  # 导入字体管理器
from datetime import date, datetime  # 导入日期时间模块

# 更新字体路径，根据 fc-list 命令的输出进行调整
font_path = 'SimHei.ttf'  # 设置字体路径为 SimHei.ttf（黑体）
fontprop = fm.FontProperties(fname=font_path, family='SimHei')  # 创建字体属性

# 刷新字体缓存
fm.fontManager.addfont(font_path)  # 添加字体到字体管理器

# 设置 SimHei 为整个图表的默认字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置无衬线字体为 SimHei
plt.rcParams['axes.unicode_minus'] = False  # 用于正确显示负号


class SupportPressureTester:
    def __init__(self, min15_path, min5_path, window_sizes=[24, 48, 72]):
        """初始化测试器"""
        # 读取分时数据
        self.df_15min = pd.read_csv(min15_path)  # 读取 15 分钟 K 线数据
        self.df_5min = pd.read_csv(min5_path)  # 读取 5 分钟 K 线数据

        # 确保日期格式正确
        self.df_15min['date'] = pd.to_datetime(self.df_15min['date'])  # 将日期列转换为日期时间格式
        self.df_5min['date'] = pd.to_datetime(self.df_5min['date'])  # 将日期列转换为日期时间格式

        # 按日期排序
        self.df_15min = self.df_15min.sort_values('date').reset_index(drop=True)  # 按日期排序并重置索引
        self.df_5min = self.df_5min.sort_values('date').reset_index(drop=True)  # 按日期排序并重置索引

        self.window_sizes = window_sizes  # 设置窗口大小列表
        self.results = []  # 初始化结果列表

        print(f"数据范围: {self.df_15min['date'].min().strftime('%Y-%m-%d %H:%M')} 至 {self.df_15min['date'].max().strftime('%Y-%m-%d %H:%M')}")  # 打印数据范围

    def calculate_psychological_levels(self, current_price, range_percent=0.05):
        """计算心理关口位"""
        levels = {}  # 初始化关口位字典

        # 确定价格范围
        price_range_low = current_price * (1 - range_percent)  # 计算价格范围下限
        price_range_high = current_price * (1 + range_percent)  # 计算价格范围上限

        # 生成可能的心理关口
        thousands = [i * 1000 for i in range(int(price_range_low/1000), int(price_range_high/1000) + 1)]  # 生成整千位关口
        hundreds = [i * 100 for i in range(int(price_range_low/100), int(price_range_high/100) + 1)]  # 生成整百位关口
        fifties = [i * 50 for i in range(int(price_range_low/50), int(price_range_high/50) + 1)]  # 生成半位关口
        special = [5000, 5500, 6000, 6500, 7000]  # 定义特殊关口

        all_levels = {
            '整千位': thousands,  # 整千位关口列表
            '整百位': hundreds,  # 整百位关口列表
            '半位': fifties,  # 半位关口列表
            '特殊关口': special  # 特殊关口列表
        }

        for level_type, numbers in all_levels.items():  # 遍历所有关口类型和关口值
            for number in numbers:  # 遍历每个关口值
                if price_range_low <= number <= price_range_high:  # 如果关口值在价格范围内
                    if number < current_price:  # 如果关口值小于当前价格，则为支撑位
                        levels[f'支撑位_心理_{level_type}_{number}'] = number  # 将关口值添加到支撑位字典
                    elif number > current_price:  # 如果关口值大于当前价格，则为压力位
                        levels[f'压力位_心理_{level_type}_{number}'] = number  # 将关口值添加到压力位字典

        return levels  # 返回关口位字典

    def calculate_fibonacci_projections(self, data, is_breakout_high=True):
        """计算斐波那契投射位"""
        high = data['high'].max()  # 获取最高价
        low = data['low'].min()  # 获取最低价
        diff = high - low  # 计算价差

        if is_breakout_high:  # 如果是突破新高
            return {
                '压力位_Fib_1.272': high + diff * 0.272,  # 计算 1.272 倍斐波那契投射位作为压力位
                '压力位_Fib_1.414': high + diff * 0.414,  # 计算 1.414 倍斐波那契投射位作为压力位
                '压力位_Fib_1.618': high + diff * 0.618   # 计算 1.618 倍斐波那契投射位作为压力位
            }
        else:  # 如果是突破新低
            return {
                '支撑位_Fib_0.786': low - diff * 0.214,  # 计算 0.786 倍斐波那契投射位作为支撑位
                '支撑位_Fib_0.618': low - diff * 0.382,  # 计算 0.618 倍斐波那契投射位作为支撑位
                '支撑位_Fib_0.5': low - diff * 0.5      # 计算 0.5 倍斐波那契投射位作为支撑位
            }

    def calculate_volatility_based_levels(self, data, is_breakout_high=True):
        """基于波动率计算潜在位置"""
        high = data['high']  # 获取最高价序列
        low = data['low']  # 获取最低价序列
        close = data['close'].shift(1)  # 获取前一周期收盘价序列
        tr1 = high - low  # 计算真实波幅 TR1
        tr2 = abs(high - close)  # 计算真实波幅 TR2
        tr3 = abs(low - close)  # 计算真实波幅 TR3
        tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 计算真实波幅 TR
        atr = tr.rolling(window=14).mean().iloc[-1]  # 计算平均真实波幅 ATR

        current_price = data['close'].iloc[-1]  # 获取当前价格

        if is_breakout_high:  # 如果是突破新高
            return {
                '压力位_ATR_1': current_price + atr,  # 计算 ATR 的 1 倍作为压力位
                '压力位_ATR_2': current_price + atr * 2,  # 计算 ATR 的 2 倍作为压力位
                '压力位_ATR_3': current_price + atr * 3   # 计算 ATR 的 3 倍作为压力位
            }
        else:  # 如果是突破新低
            return {
                '支撑位_ATR_1': current_price - atr,  # 计算 ATR 的 1 倍作为支撑位
                '支撑位_ATR_2': current_price - atr * 2,  # 计算 ATR 的 2 倍作为支撑位
                '支撑位_ATR_3': current_price - atr * 3   # 计算 ATR 的 3 倍作为支撑位
            }

    def calculate_traditional_levels(self, data_15min, data_5min):
        """计算传统支撑压力位"""
        if len(data_15min) == 0 or len(data_5min) == 0:  # 如果数据为空，则返回空字典
            return {'支撑位': {}, '压力位': {}, '趋势': 'unknown'}  # 返回空字典

        # 使用15分钟数据计算
        highs = data_15min['high'].values  # 获取最高价数组
        lows = data_15min['low'].values  # 获取最低价数组
        closes = data_15min['close'].values  # 获取收盘价数组
        volumes = data_15min['volume'].values  # 获取成交量数组
        current_price = closes[-1]  # 获取当前价格

        # 计算VWAP
        vwap = np.average(closes, weights=volumes)  # 计算成交量加权平均价 VWAP

        # 计算移动平均
        ma20 = np.mean(closes[-20:]) if len(closes) >= 20 else np.mean(closes)  # 计算 20 周期移动平均线 MA20
        ma50 = np.mean(closes[-50:]) if len(closes) >= 50 else np.mean(closes)  # 计算 50 周期移动平均线 MA50

        levels = {'支撑位': {}, '压力位': {}, '趋势': 'up' if ma20 > ma50 else 'down'}  # 初始化关口位字典，并根据 MA20 和 MA50 判断趋势

        # 分配VWAP和MA
        if vwap < current_price:  # 如果 VWAP 小于当前价格，则为支撑位
            levels['支撑位']['支撑位_VWAP'] = vwap  # 将 VWAP 添加到支撑位字典
        else:  # 如果 VWAP 大于当前价格，则为压力位
            levels['压力位']['压力位_VWAP'] = vwap  # 将 VWAP 添加到压力位字典

        if ma20 < current_price:  # 如果 MA20 小于当前价格，则为支撑位
            levels['支撑位']['支撑位_MA20'] = ma20  # 将 MA20 添加到支撑位字典
        else:  # 如果 MA20 大于当前价格，则为压力位
            levels['压力位']['压力位_MA20'] = ma20  # 将 MA20 添加到压力位字典

        if ma50 < current_price:  # 如果 MA50 小于当前价格，则为支撑位
            levels['支撑位']['支撑位_MA50'] = ma50  # 将 MA50 添加到支撑位字典
        else:  # 如果 MA50 大于当前价格，则为压力位
            levels['压力位']['压力位_MA50'] = ma50  # 将 MA50 添加到压力位字典

        return levels  # 返回关口位字典

    def calculate_level_strength(self, level_price, data_15min, data_5min):
        """计算支撑位/压力位的强度分数 (0-1)

        参数：
        level_price: float, 价格水平
        data_15min: DataFrame, 15分钟K线数据
        data_5min: DataFrame, 5分钟K线数据

        返回：
        float: 强度分数 (0-1)
        """
        strength_score = 0.0  # 初始化强度分数
        current_price = data_15min['close'].iloc[-1]  # 获取当前价格

        # 1. 价格接触频率 (25%)
        price_range = 0.002  # 0.2%的价格范围
        touches_15min = len(data_15min[
            (data_15min['low'] >= level_price * (1 - price_range)) &  # 15 分钟 K 线的最低价在价格水平范围内
            (data_15min['high'] <= level_price * (1 + price_range))  # 15 分钟 K 线的最高价在价格水平范围内
        ])
        touches_5min = len(data_5min[
            (data_5min['low'] >= level_price * (1 - price_range)) &  # 5 分钟 K 线的最低价在价格水平范围内
            (data_5min['high'] <= level_price * (1 + price_range))  # 5 分钟 K 线的最高价在价格水平范围内
        ])

        touch_score = min((touches_15min / len(data_15min) + touches_5min / len(data_5min)) / 2, 1)  # 计算价格接触频率得分
        strength_score += touch_score * 0.25  # 将价格接触频率得分添加到总强度分数

        # 2. 成交量支持度 (25%)
        volume_near_level_15min = data_15min[
            (data_15min['low'] >= level_price * 0.995) &  # 15 分钟 K 线的最低价在价格水平附近
            (data_15min['high'] <= level_price * 1.005)  # 15 分钟 K 线的最高价在价格水平附近
        ]['volume'].sum()  # 计算价格水平附近的成交量总和
        volume_score = min(volume_near_level_15min / data_15min['volume'].sum(), 1)  # 计算成交量支持度得分
        strength_score += volume_score * 0.25  # 将成交量支持度得分添加到总强度分数

        # 3. 价格反应强度 (25%)
        def calculate_reaction_strength(df, is_support):
            """计算价格反应强度"""
            reactions = []  # 初始化价格反应列表
            for i in range(1, len(df)):  # 遍历 K 线数据
                prev_price = df['close'].iloc[i-1]  # 获取前一周期收盘价
                curr_price = df['close'].iloc[i]  # 获取当前周期收盘价
                if is_support:  # 如果是支撑位
                    if abs(prev_price - level_price) / level_price < 0.003:  # 如果前一周期收盘价在价格水平附近
                        reaction = (curr_price - prev_price) / prev_price  # 计算价格反应
                        reactions.append(reaction)  # 将价格反应添加到列表
                else:  # 如果是压力位
                    if abs(prev_price - level_price) / level_price < 0.003:  # 如果前一周期收盘价在价格水平附近
                        reaction = (prev_price - curr_price) / prev_price  # 计算价格反应
                        reactions.append(reaction)  # 将价格反应添加到列表
            return np.mean(reactions) if reactions else 0  # 返回价格反应的平均值

        is_support = level_price < current_price  # 判断价格水平是支撑位还是压力位
        reaction_15min = calculate_reaction_strength(data_15min, is_support)  # 计算 15 分钟 K 线的价格反应强度
        reaction_5min = calculate_reaction_strength(data_5min, is_support)  # 计算 5 分钟 K 线的价格反应强度
        reaction_score = min((abs(reaction_15min) + abs(reaction_5min)) / 2 * 100, 1)  # 计算价格反应强度得分
        strength_score += reaction_score * 0.25  # 将价格反应强度得分添加到总强度分数

        # 4. 成交量突破确认度 (25%)
        def calculate_volume_confirmation(df):
            """计算成交量突破确认度"""
            if len(df) < 2:  # 如果数据不足，则返回 0
                return 0

            near_level = df[
                (df['low'] >= level_price * 0.995) &  # K 线的最低价在价格水平附近
                (df['high'] <= level_price * 1.005)  # K 线的最高价在价格水平附近
            ]

            if len(near_level) == 0:  # 如果没有价格水平附近的数据，则返回 0
                return 0

            avg_volume = df['volume'].mean()  # 计算平均成交量
            max_volume_near = near_level['volume'].max()  # 计算价格水平附近的最大成交量

            return min(max_volume_near / avg_volume, 1)  # 返回成交量突破确认度得分

        volume_conf_15min = calculate_volume_confirmation(data_15min)  # 计算 15 分钟 K 线的成交量突破确认度
        volume_conf_5min = calculate_volume_confirmation(data_5min)  # 计算 5 分钟 K 线的成交量突破确认度
        volume_conf_score = (volume_conf_15min + volume_conf_5min) / 2  # 计算成交量突破确认度得分
        strength_score += volume_conf_score * 0.25  # 将成交量突破确认度得分添加到总强度分数

        return round(strength_score, 3)  # 返回强度分数，保留 3 位小数

    def filter_levels(levels_dict):
        """过滤支撑压力位，去除过于接近的水平"""
        sorted_levels = dict(sorted(levels_dict.items(), key=lambda x: x[1]))  # 按价格排序
        filtered_levels = {}  # 初始化过滤后的水平字典
        last_level = None  # 初始化上一个水平
        # 增加最小距离阈值
        min_distance = current_price * 0.005  # 设置最小距离阈值

        for key, value in sorted_levels.items():  # 遍历排序后的水平
            if last_level is None or abs(value - last_level) >= min_distance:  # 如果当前水平与上一个水平的距离大于最小距离阈值
                filtered_levels[key] = value  # 将当前水平添加到过滤后的水平字典
                last_level = value  # 更新上一个水平

        return filtered_levels  # 返回过滤后的水平字典

    def calculate_efficacy(self, levels, test_15min, test_5min):
        """计算支撑压力位有效性"""
        efficacy = {'支撑位': {}, '压力位': {}}  # 初始化有效性字典

        if len(test_15min) < 3 or len(test_5min) < 3:  # 如果测试数据不足，则返回空字典
            return efficacy  # 返回空字典

        # 计算ATR
        def calculate_atr(df):
            """计算平均真实波幅 ATR"""
            high = df['high']  # 获取最高价序列
            low = df['low']  # 获取最低价序列
            close = df['close'].shift(1)  # 获取前一周期收盘价序列
            tr1 = high - low  # 计算真实波幅 TR1
            tr2 = abs(high - close)  # 计算真实波幅 TR2
            tr3 = abs(low - close)  # 计算真实波幅 TR3
            tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 计算真实波幅 TR
            return tr.mean()  # 返回平均真实波幅 ATR

        atr_15 = calculate_atr(test_15min)  # 计算 15 分钟 K 线的 ATR
        atr_5 = calculate_atr(test_5min)  # 计算 5 分钟 K 线的 ATR

        # 设置阈值
        threshold_15 = min(max(atr_15 / test_15min['close'].mean(), 0.001), 0.005)  # 设置 15 分钟 K 线的阈值
        threshold_5 = min(max(atr_5 / test_5min['close'].mean(), 0.0005), 0.003)  # 设置 5 分钟 K 线的阈值

        for level_type in ['支撑位', '压力位']:  # 遍历支撑位和压力位
            level_dict = levels[level_type]  # 获取当前类型的水平字典
            for key, level_info in level_dict.items():  # 遍历每个水平
                level_price = level_info['price']  # 获取水平价格
                is_valid = False  # 初始化有效性标志

                if level_type == '支撑位':  # 如果是支撑位
                    touched_15 = (test_15min['low'] <= level_price * (1 + threshold_15)).any()  # 判断 15 分钟 K 线是否触及支撑位
                    if touched_15:  # 如果触及支撑位
                        idx_15 = test_15min[test_15min['low'] <= level_price * (1 + threshold_15)].index[0]  # 获取触及支撑位的索引
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及支撑位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及支撑位之后的数据

                        if len(post_touch_5) > 0:  # 如果有触及支撑位之后的数据
                            bounce_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['low'].min()  # 计算 5 分钟 K 线的反弹幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 判断是否有成交量激增
                            is_valid = bounce_5 > threshold_5 * 2 and volume_surge  # 判断支撑位是否有效

                else:  # 如果是压力位
                    touched_15 = (test_15min['high'] >= level_price * (1 - threshold_15)).any()  # 判断 15 分钟 K 线是否触及压力位
                    if touched_15:  # 如果触及压力位
                        idx_15 = test_15min[test_15min['high'] >= level_price * (1 - threshold_15)].index[0]  # 获取触及压力位的索引
                        touch_time = test_15min.loc[idx_15, 'date']  # 获取触及压力位的时间
                        post_touch_5 = test_5min[test_5min['date'] >= touch_time]  # 获取触及压力位之后的数据

                        if len(post_touch_5) > 0:  # 如果有触及压力位之后的数据
                            drop_5 = (post_touch_5['high'].max() - post_touch_5['low'].min()) / post_touch_5['high'].max()  # 计算 5 分钟 K 线的回落幅度
                            volume_surge = (post_touch_5['volume'] > post_touch_5['volume'].mean() * 1.2).any()  # 判断是否有成交量激增
                            is_valid = drop_5 > threshold_5 * 2 and volume_surge  # 判断压力位是否有效

                efficacy[level_type][key] = is_valid  # 将有效性标志添加到有效性字典

        return efficacy  # 返回有效性字典

    def calculate_levels(self, data_15min, data_5min):
        """计算所有支撑压力位并计算强度"""
        levels = {'支撑位': {}, '压力位': {}, '趋势': 'unknown'}  # 初始化关口位字典
        current_price = data_15min['close'].iloc[-1]  # 获取当前价格

        # 获取所有可能的价格水平
        all_levels = {}  # 初始化所有水平字典

        # 添加传统支撑压力位
        traditional_levels = self.calculate_traditional_levels(data_15min, data_5min)  # 计算传统支撑压力位
        for key, value in traditional_levels.items():  # 遍历传统支撑压力位
            if isinstance(value, dict):  # 如果值是字典类型
                all_levels.update(value)  # 将值添加到所有水平字典

        # 添加心理关口
        psychological_levels = self.calculate_psychological_levels(current_price)  # 计算心理关口位
        all_levels.update(psychological_levels)  # 将心理关口位添加到所有水平字典

        # 判断是否突破新高/新低并添加相应的水平
        is_breakout_high = current_price >= data_15min['high'].max()  # 判断是否突破新高
        is_breakout_low = current_price <= data_15min['low'].min()  # 判断是否突破新低

        if is_breakout_high:  # 如果突破新高
            all_levels.update(self.calculate_fibonacci_projections(data_15min, True))  # 计算斐波那契投射位作为压力位
            all_levels.update(self.calculate_volatility_based_levels(data_15min, True))  # 计算基于波动率的压力位
        if is_breakout_low:  # 如果突破新低
            all_levels.update(self.calculate_fibonacci_projections(data_15min, False))  # 计算斐波那契投射位作为支撑位
            all_levels.update(self.calculate_volatility_based_levels(data_15min, False))  # 计算基于波动率的支撑位

        # 为每个水平计算强度并分类
        for key, price in all_levels.items():  # 遍历所有水平
            if isinstance(price, (int, float)):  # 如果价格是数值类型
                strength = self.calculate_level_strength(price, data_15min, data_5min)  # 计算水平强度

                level_info = {
                    'price': price,  # 水平价格
                    'strength': strength  # 水平强度
                }

                if price < current_price:  # 如果价格小于当前价格，则为支撑位
                    levels['支撑位'][key] = level_info  # 将水平信息添加到支撑位字典
                else:  # 如果价格大于当前价格，则为压力位
                    levels['压力位'][key] = level_info  # 将水平信息添加到压力位字典

        # 设置趋势
        levels['趋势'] = traditional_levels.get('趋势', 'unknown')  # 设置趋势

        # 过滤和排序最强的位置
        levels['支撑位'] = dict(sorted(levels['支撑位'].items(),
                                    key=lambda x: x[1]['strength'], reverse=True)[:5])  # 过滤和排序支撑位，保留强度最高的 5 个
        levels['压力位'] = dict(sorted(levels['压力位'].items(),
                                    key=lambda x: x[1]['strength'], reverse=True)[:5])  # 过滤和排序压力位，保留强度最高的 5 个

        return levels  # 返回关口位字典


    def run_backtest(self):
        """运行回测"""
        self.results = []  # 初始化结果列表

        for window_size in self.window_sizes:  # 遍历窗口大小
            print(f"\n正在测试 {window_size} 小时窗口...")  # 打印测试信息
            window_results = []  # 初始化窗口结果列表

            # 计算总测试周期
            total_hours = int((self.df_15min['date'].max() - self.df_15min['date'].min()).total_seconds() / 3600)  # 计算总测试周期（小时）
            test_periods = total_hours - window_size  # 计算测试周期数

            for i in tqdm(range(test_periods)):  # 遍历测试周期
                end_time = self.df_15min['date'].max() - pd.Timedelta(hours=i)  # 计算训练数据结束时间
                start_time = end_time - pd.Timedelta(hours=window_size)  # 计算训练数据开始时间
                test_start = end_time  # 计算测试数据开始时间
                test_end = end_time + pd.Timedelta(hours=1)  # 计算测试数据结束时间

                # 获取训练数据
                train_15min = self.df_15min[
                    (self.df_15min['date'] >= start_time) &  # 15 分钟 K 线数据在训练时间范围内
                    (self.df_15min['date'] < end_time)  # 15 分钟 K 线数据在训练时间范围内
                ].copy()  # 复制训练数据

                train_5min = self.df_5min[
                    (self.df_5min['date'] >= start_time) &  # 5 分钟 K 线数据在训练时间范围内
                    (self.df_5min['date'] < end_time)  # 5 分钟 K 线数据在训练时间范围内
                ].copy()  # 复制训练数据

                # 获取测试数据
                test_15min = self.df_15min[
                    (self.df_15min['date'] >= test_start) &  # 15 分钟 K 线数据在测试时间范围内
                    (self.df_15min['date'] < test_end)  # 15 分钟 K 线数据在测试时间范围内
                ].copy()  # 复制测试数据

                test_5min = self.df_5min[
                    (self.df_5min['date'] >= test_start) &  # 5 分钟 K 线数据在测试时间范围内
                    (self.df_5min['date'] < test_end)  # 5 分钟 K 线数据在测试时间范围内
                ].copy()  # 复制测试数据

                if len(train_15min) == 0 or len(test_15min) == 0:  # 如果训练数据或测试数据为空，则跳过本次循环
                    continue  # 跳过本次循环

                # 计算支撑压力位
                levels = self.calculate_levels(train_15min, train_5min)  # 计算支撑压力位

                # 验证结果
                efficacy = self.calculate_efficacy(levels, test_15min, test_5min)  # 计算支撑压力位有效性

                window_results.append({
                    '训练开始': start_time,  # 训练数据开始时间
                    '训练结束': end_time,  # 训练数据结束时间
                    '测试时间': test_start,  # 测试数据开始时间
                    '支撑压力位': levels,  # 支撑压力位
                    '验证结果': efficacy  # 支撑压力位有效性
                })  # 将结果添加到窗口结果列表

            self.results.append({
                '窗口大小': window_size,  # 窗口大小
                '结果': window_results  # 窗口结果列表
            })  # 将窗口结果添加到总结果列表

            # 分析窗口表现
            self.analyze_window_performance(window_results)  # 分析窗口表现


    def analyze_window_performance(self, results):
        """分析窗口表现"""
        total_support = 0  # 初始化支撑位总数
        valid_support = 0  # 初始化有效支撑位数
        total_resistance = 0  # 初始化压力位总数
        valid_resistance = 0  # 初始化有效压力位数

        for result in results:  # 遍历结果
            efficacy = result['验证结果']  # 获取支撑压力位有效性

            for key, valid in efficacy['支撑位'].items():  # 遍历支撑位
                total_support += 1  # 支撑位总数加 1
                if valid:  # 如果支撑位有效
                    valid_support += 1  # 有效支撑位数加 1

            for key, valid in efficacy['压力位'].items():  # 遍历压力位
                total_resistance += 1  # 压力位总数加 1
                if valid:  # 如果压力位有效
                    valid_resistance += 1  # 有效压力位数加 1

        print("\n窗口表现分析:")  # 打印分析结果标题
        print(f"总体样本数: {len(results)}")  # 打印样本数
        if total_support > 0:  # 如果支撑位总数大于 0
            print(f"支撑位准确率: {valid_support/total_support*100:.2f}% (样本数: {total_support})")  # 打印支撑位准确率
        if total_resistance > 0:  # 如果压力位总数大于 0
            print(f"压力位准确率: {valid_resistance/total_resistance*100:.2f}% (样本数: {total_resistance})")  # 打印压力位准确率

    def print_latest_result(self):
        """打印最新的支撑压力位预测结果"""
        latest_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近 24 小时的 15 分钟 K 线数据
        latest_24h_5min = self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近 24 小时的 5 分钟 K 线数据

        latest_levels = self.calculate_levels(latest_24h, latest_24h_5min)  # 计算最新的支撑压力位
        current_price = latest_24h['close'].iloc[-1]  # 获取当前价格

        print("\n=== 最新预测结果 ===")  # 打印预测结果标题
        print(f"当前价格: {current_price:.2f}")  # 打印当前价格
        print(f"市场趋势: {latest_levels['趋势']}")  # 打印市场趋势

        def print_levels(levels, level_type):
            """打印支撑位或压力位"""
            if levels:  # 如果水平不为空
                print(f"\n{level_type}:")  # 打印水平类型
                # 根据价格距离排序
                sorted_levels = sorted(levels.items(),
                                    key=lambda x: abs(x[1]['price'] - current_price))  # 按价格距离排序

                for key, level_info in sorted_levels:  # 遍历排序后的水平
                    price = level_info['price']  # 获取水平价格
                    strength = level_info['strength']  # 获取水平强度

                    if level_type == "支撑位":  # 如果是支撑位
                        distance = (current_price - price) / current_price * 100  # 计算价格距离（百分比）
                    else:  # 如果是压力位
                        distance = (price - current_price) / current_price * 100  # 计算价格距离（百分比）

                    # 确定强度描述
                    if strength >= 0.7:  # 如果强度大于等于 0.7，则为强
                        strength_desc = "强"  # 设置强度描述为强
                    elif strength >= 0.4:  # 如果强度大于等于 0.4，则为中
                        strength_desc = "中"  # 设置强度描述为中
                    else:  # 如果强度小于 0.4，则为弱
                        strength_desc = "弱"  # 设置强度描述为弱

                    if distance < 0.5:  # 如果价格距离小于 0.5%，则强度描述加 +
                        strength_desc += "+"  # 强度描述加 +

                    print(f"{key}: {price:.2f} (距当前价格: {distance:.2f}%, 强度: {strength_desc} [{strength:.2f}])")  # 打印水平信息

        print_levels(latest_levels['支撑位'], "支撑位")  # 打印支撑位
        print_levels(latest_levels['压力位'], "压力位")  # 打印压力位


    def plot_results(self):
        """绘制支撑压力位和价格走势，包含强度信息"""
        import matplotlib.pyplot as plt  # 导入 Matplotlib 库
        from matplotlib.gridspec import GridSpec  # 导入 GridSpec
        import matplotlib.dates as mdates  # 导入日期时间格式化工具

        # 获取最近24小时的数据用于绘图
        last_24h = self.df_15min[self.df_15min['date'] >= (self.df_15min['date'].max() - pd.Timedelta(hours=24))]  # 获取最近 24 小时的 15 分钟 K 线数据

        # 创建图表
        fig = plt.figure(figsize=(15, 10))  # 创建图表对象，设置图表大小
        gs = GridSpec(2, 1, height_ratios=[3, 1])  # 创建 GridSpec 对象，设置子图比例

        # 设置背景色
        fig.patch.set_facecolor('#F0F3F5')  # 设置图表背景色

        # 定义颜色方案
        support_colors = ['#27AE60', '#2ECC71', '#82E0AA']  # 支撑位颜色方案
        resistance_colors = ['#C0392B', '#E74C3C', '#F1948A']  # 压力位颜色方案

        # 价格走势和支撑压力位
        ax1 = fig.add_subplot(gs[0])  # 创建价格走势子图
        ax2 = fig.add_subplot(gs[1])  # 创建成交量子图

        # 设置子图背景色
        ax1.set_facecolor('#FFFFFF')  # 设置价格走势子图背景色
        ax2.set_facecolor('#FFFFFF')  # 设置成交量子图背景色

        # 添加网格
        ax1.grid(True, linestyle='--', alpha=0.3)  # 为价格走势子图添加网格
        ax2.grid(True, linestyle='--', alpha=0.3)  # 为成交量子图添加网格

        # 绘制K线图
        ax1.plot(last_24h['date'], last_24h['close'],
                color='#2C3E50', linewidth=1.5, label='收盘价',
                zorder=5)  # 绘制收盘价曲线

        # 绘制价格区间
        ax1.fill_between(last_24h['date'], last_24h['high'], last_24h['low'],
                        color='#BDC3C7', alpha=0.3, label='价格区间',
                        zorder=4)  # 绘制价格区间

        # 获取最新的支撑压力位
        latest_levels = self.calculate_levels(
            last_24h,
            self.df_5min[self.df_5min['date'] >= (self.df_5min['date'].max() - pd.Timedelta(hours=24))]
        )  # 计算最新的支撑压力位

        # 绘制支撑位
        for i, (key, level_info) in enumerate(latest_levels['支撑位'].items()):  # 遍历支撑位
            price = level_info['price']  # 获取支撑位价格
            strength = level_info['strength']  # 获取支撑位强度
            color = support_colors[min(i, len(support_colors)-1)]  # 获取支撑位颜色
            style = '-' if '心理' in key else '--'  # 设置支撑位线条样式
            alpha = 0.3 + strength * 0.7  # 设置支撑位线条透明度
            ax1.axhline(y=price, color=color, linestyle=style, alpha=alpha,
                      label=f'{key}: {price:.2f} (强度: {strength:.2f})',
                      zorder=3)  # 绘制支撑位水平线

        # 绘制压力位
        for i, (key, level_info) in enumerate(latest_levels['压力位'].items()):  # 遍历压力位
            price = level_info['price']  # 获取压力位价格
            strength = level_info['strength']  # 获取压力位强度
            color = resistance_colors[min(i, len(resistance_colors)-1)]  # 获取压力位颜色
            style = '-' if '心理' in key else '--'  # 设置压力位线条样式
            alpha = 0.3 + strength * 0.7  # 设置压力位线条透明度
            ax1.axhline(y=price, color=color, linestyle=style, alpha=alpha,
                      label=f'{key}: {price:.2f} (强度: {strength:.2f})',
                      zorder=3)  # 绘制压力位水平线

        # 绘制成交量
        for i in range(len(last_24h)):  # 遍历 K 线数据
            if i > 0:  # 如果不是第一根 K 线
                color = '#2ECC71' if last_24h['close'].iloc[i] >= last_24h['close'].iloc[i-1] else '#E74C3C'  # 根据收盘价变化设置成交量颜色
            else:  # 如果是第一根 K 线
                color = '#2ECC71'  # 设置成交量颜色为绿色

            ax2.bar(last_24h['date'].iloc[i], last_24h['volume'].iloc[i],
                    width=pd.Timedelta(minutes=10),  # 设置成交量柱子宽度
                    color=color, alpha=0.7)  # 绘制成交量柱子

        # 设置时间格式
        date_formatter = mdates.DateFormatter('%H:%M')  # 创建日期时间格式化对象
        ax1.xaxis.set_major_formatter(date_formatter)  # 设置价格走势子图 X 轴时间格式
        ax2.xaxis.set_major_formatter(date_formatter)  # 设置成交量子图 X 轴时间格式

        # 设置标题和标签
        ax1.set_title('价格走势与支撑压力位 (最近24小时)', fontsize=14, pad=20)  # 设置价格走势子图标题
        ax1.set_xlabel('时间', fontsize=12)  # 设置价格走势子图 X 轴标签
        ax1.set_ylabel('价格', fontsize=12)  # 设置价格走势子图 Y 轴标签

        ax2.set_title('成交量', fontsize=14, pad=20)  # 设置成交量子图标题
        ax2.set_xlabel('时间', fontsize=12)  # 设置成交量子图 X 轴标签
        ax2.set_ylabel('成交量', fontsize=12)  # 设置成交量子图 Y 轴标签

        # 优化刻度标签
        for ax in [ax1, ax2]:  # 遍历子图
            ax.tick_params(axis='both', labelsize=10)  # 设置刻度标签大小
            plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')  # 旋转 X 轴刻度标签

        # 优化图例位置和样式
        ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10,
                  facecolor='white', edgecolor='none', framealpha=0.8)  # 设置图例样式

        # 添加图表说明
        current_price = last_24h['close'].iloc[-1]  # 获取当前价格
        trend = latest_levels.get('趋势', 'unknown')  # 获取市场趋势
        trend_text = '上涨' if trend == 'up' else '下跌' if trend == 'down' else '未知'  # 设置市场趋势文本

        # 使用文本框添加说明
        textstr = f'当前价格: {current_price:.2f}\n市场趋势: {trend_text}'  # 设置图表说明文本
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)  # 设置文本框样式
        ax1.text(0.02, 0.98, textstr, transform=ax1.transAxes,
                fontsize=12, verticalalignment='top',
                bbox=props)  # 添加图表说明文本框

        plt.tight_layout()  # 调整子图布局
        plt.show()  # 显示图表

tester = SupportPressureTester(
    min15_path='hstech_data_15min.csv',  # 设置 15 分钟 K 线数据文件路径
    min5_path='hstech_data_5min.csv',  # 设置 5 分钟 K 线数据文件路径
    window_sizes=[24, 48, 72]  # 设置窗口大小列表
)  # 创建 SupportPressureTester 对象
tester.run_backtest()  # 运行回测
tester.plot_results()  # 绘制结果图表
tester.print_latest_result()  # 打印最新的预测结果
# Out:
# --2025-02-20 15:58:14--  https://raw.githubusercontent.com/StellarCN/scp_zh/refs/heads/master/fonts/SimHei.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9751960 (9.3M) [application/octet-stream]
# Saving to: ‘SimHei.ttf.10’
#
# SimHei.ttf.10       100%[===================>]   9.30M  --.-KB/s    in 0.06s
#
# 2025-02-20 15:58:14 (158 MB/s) - ‘SimHei.ttf.10’ saved [9751960/9751960]
#
# 数据范围: 2025-01-20 09:45 至 2025-02-19 16:00
#
# 正在测试 24 小时窗口...
# 100%|██████████| 702/702 [00:14<00:00, 49.50it/s]
# 窗口表现分析:
# 总体样本数: 146
# 支撑位准确率: 36.81% (样本数: 470)
# 压力位准确率: 35.53% (样本数: 470)
#
# 正在测试 48 小时窗口...
# 100%|██████████| 678/678 [00:15<00:00, 42.86it/s]
# 窗口表现分析:
# 总体样本数: 138
# 支撑位准确率: 35.73% (样本数: 445)
# 压力位准确率: 34.16% (样本数: 445)
#
# 正在测试 72 小时窗口...
# ...

# %%
from IPython import get_ipython  # 导入 IPython 库
from IPython.display import display  # 导入 display 函数，用于在 Notebook 中显示内容
# %%
import pandas as pd  # 导入 pandas 库，用于数据处理
import numpy as np  # 导入 numpy 库，用于数值计算
from sklearn.cluster import KMeans  # 导入 KMeans 聚类算法
from tqdm import tqdm  # 导入 tqdm 库，用于显示进度条
from scipy.signal import argrelextrema  # 导入 argrelextrema 函数，用于寻找极值点


class SupportResistanceTester:
    """
    支撑阻力位测试器
    """

    def __init__(self, data_path, window_size=30, test_period=7):
        """
        初始化函数
        :param data_path: 数据文件路径
        :param window_size: 训练窗口大小
        :param test_period: 测试周期长度
        """
        self.df = self._load_data(data_path)  # 加载数据
        self.window_size = window_size  # 设置训练窗口大小
        self.test_period = test_period  # 设置测试周期长度
        self.results = []  # 存储回测结果

    def _load_data(self, path):
        """
        加载数据
        :param path: 数据文件路径
        :return: pandas DataFrame 格式的数据
        """
        df = pd.read_csv(path, parse_dates=['date'])  # 读取 CSV 文件，并将 'date' 列解析为日期时间格式
        df = df.sort_values('date').set_index('date')  # 按日期排序，并将 'date' 列设置为索引
        df = df[~df.index.duplicated(keep='first')]  # 去除重复索引，保留第一个
        return df  # 返回 DataFrame 格式的数据

    def _generate_windows(self):
        """
        改进的窗口生成器
        :yield: 训练数据和测试数据
        """
        dates = self.df.index  # 获取日期索引
        total_length = len(dates)  # 获取数据长度
        step = 1  # 每次滑动1个单位

        for i in range(0, total_length - self.window_size - self.test_period, step):
            train_start = dates[i]  # 训练数据开始日期
            train_end = dates[i + self.window_size - 1]  # 训练数据结束日期
            test_start = dates[i + self.window_size]  # 测试数据开始日期
            test_end = dates[i + self.window_size + self.test_period - 1]  # 测试数据结束日期

            # 确保测试期有足够数据
            if len(self.df.loc[test_start:test_end]) < self.test_period:
                continue  # 如果测试数据不足，跳过当前循环

            train_data = self.df.loc[train_start:train_end]  # 获取训练数据
            test_data = self.df.loc[test_start:test_end]  # 获取测试数据

            yield train_data, test_data  # 返回训练数据和测试数据

    def _calculate_levels(self, df):
        """
        改进的点位计算方法
        :param df: 数据
        :return: 支撑位和阻力位
        """
        try:
            # 基础点位
            current_price = df['close'].iloc[-1]  # 获取当前价格
            round_levels = {
                'support': np.floor(current_price / 100) * 100,  # 计算基础支撑位
                'resistance': np.ceil(current_price / 100) * 100  # 计算基础阻力位
            }

            # 近期高低点
            recent = df[-20:]  # 获取最近20个数据
            extreme_levels = {
                'support': recent['low'].min(),  # 计算近期最低点作为支撑位
                'resistance': recent['high'].max()  # 计算近期最高点作为阻力位
            }

            # 斐波那契
            swing_high = recent['high'].max()  # 获取近期最高点
            swing_low = recent['low'].min()  # 获取近期最低点
            delta = swing_high - swing_low  # 计算波动幅度
            fib_levels = {
                'support': swing_high - delta * 0.618,  # 计算斐波那契支撑位
                'resistance': swing_high - delta * 0.382  # 计算斐波那契阻力位
            }

            # 布林带
            ma = df['close'].rolling(20).mean()  # 计算20日移动平均线
            std = df['close'].rolling(20).std()  # 计算20日标准差
            bollinger_levels = {
                'support': ma.iloc[-1] - 2 * std.iloc[-1],  # 计算布林带下轨作为支撑位
                'resistance': ma.iloc[-1] + 2 * std.iloc[-1]  # 计算布林带上轨作为阻力位
            }

            # 综合点位
            levels = {
                'support': sorted([round_levels['support'],
                                 extreme_levels['support'],
                                 fib_levels['support'],
                                 bollinger_levels['support']]),  # 合并所有支撑位并排序
                'resistance': sorted([round_levels['resistance'],
                                    extreme_levels['resistance'],
                                    fib_levels['resistance'],
                                    bollinger_levels['resistance']])  # 合并所有阻力位并排序
            }

            # 过滤异常值
            price_range = df['close'].iloc[-20:].max() - df['close'].iloc[-20:].min()  # 计算最近20个数据的价格范围
            levels['support'] = [x for x in levels['support']
                               if x >= df['close'].min() - price_range]  # 过滤异常支撑位
            levels['resistance'] = [x for x in levels['resistance']
                                  if x <= df['close'].max() + price_range]  # 过滤异常阻力位

            return levels  # 返回支撑位和阻力位

        except Exception as e:
            print(f"计算点位时出错：{str(e)}")  # 打印错误信息
            return {'support': [], 'resistance': []}  # 返回空列表

    def _test_levels(self, levels, test_data):
        """
        改进的验证方法
        :param levels: 支撑位和阻力位
        :param test_data: 测试数据
        :return: 支撑位和阻力位的成功率
        """
        if not levels['support'] or not levels['resistance']:
            return {'support_success': 0, 'resistance_success': 0}  # 如果没有支撑位或阻力位，返回0成功率

        # 支撑位验证
        support_hits = 0  # 初始化支撑位命中次数
        for s in levels['support']:  # 遍历所有支撑位
            touch = test_data['low'] <= s * 1.01  # 1%容差，判断是否触及支撑位
            if touch.any():  # 如果触及支撑位
                touch_idx = touch.idxmax()  # 获取触及支撑位的索引
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取触及支撑位后一根K线的收盘价
                    if next_close > s * 0.99:  # 反弹确认，判断是否反弹
                        support_hits += 1  # 如果反弹，支撑位命中次数加1

        # 压力位验证
        resistance_hits = 0  # 初始化阻力位命中次数
        for r in levels['resistance']:  # 遍历所有阻力位
            touch = test_data['high'] >= r * 0.99  # 1%容差，判断是否触及阻力位
            if touch.any():  # 如果触及阻力位
                touch_idx = touch.idxmax()  # 获取触及阻力位的索引
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取触及阻力位后一根K线的收盘价
                    if next_close < r * 1.01:  # 回落确认，判断是否回落
                        resistance_hits += 1  # 如果回落，阻力位命中次数加1

        return {
            'support_success': support_hits / len(levels['support']),  # 计算支撑位成功率
            'resistance_success': resistance_hits / len(levels['resistance'])  # 计算阻力位成功率
        }

    def run_backtest(self):
        """
        改进的回测执行
        :return: 回测结果
        """
        for train_data, test_data in tqdm(self._generate_windows()):  # 遍历所有窗口
            levels = self._calculate_levels(train_data)  # 计算支撑位和阻力位
            result = self._test_levels(levels, test_data)  # 验证支撑位和阻力位

            self.results.append({  # 将回测结果添加到列表中
                'train_start': train_data.index[0],  # 训练数据开始日期
                'train_end': train_data.index[-1],  # 训练数据结束日期
                'test_start': test_data.index[0],  # 测试数据开始日期
                'test_end': test_data.index[-1],  # 测试数据结束日期
                'levels': levels,  # 支撑位和阻力位
                **result  # 支撑位和阻力位的成功率
            })

        return self._analyze_results()  # 分析回测结果

    def _analyze_results(self):
        """
        改进的结果分析
        :return: 回测结果统计
        """
        df = pd.DataFrame(self.results)  # 将回测结果转换为 DataFrame 格式

        # 过滤无效测试
        df = df[(df['support_success'] >= 0) & (df['resistance_success'] >= 0)]  # 过滤成功率小于0的测试

        if len(df) == 0:
            print("没有有效的测试结果")  # 如果没有有效的测试结果，打印提示信息
            return None  # 返回 None

        print(f"\n回测结果统计（{len(df)}次有效测试）：")  # 打印回测结果统计信息
        print(f"支撑位平均成功率：{df['support_success'].mean():.2%}")  # 打印支撑位平均成功率
        print(f"压力位平均成功率：{df['resistance_success'].mean():.2%}")  # 打印阻力位平均成功率

        # 成功率分布
        print("\n成功率分布：")  # 打印成功率分布信息
        print(df[['support_success', 'resistance_success']].describe())  # 打印成功率的描述性统计信息

        return df  # 返回回测结果统计


# 使用示例
if __name__ == "__main__":
    # 日线回测
    daily_tester = SupportResistanceTester(  # 创建日线回测对象
        data_path='hstech_data_1d.csv',  # 设置数据文件路径
        window_size=30,  # 设置训练窗口大小为30天
        test_period=5  # 设置测试周期长度为5天
    )
    daily_results = daily_tester.run_backtest()  # 运行日线回测

    # 小时线回测（需调整参数）
    hourly_tester = SupportResistanceTester(  # 创建小时线回测对象
        data_path='hstech_data_5min.csv',  # 设置数据文件路径
        window_size=120,  # 设置训练窗口大小为120小时（5天）
        test_period=24  # 设置测试周期长度为24小时
    )
    hourly_results = hourly_tester.run_backtest()  # 运行小时线回测
# Out:
# 211it [00:00, 277.65it/s]
# 回测结果统计（211次有效测试）：
# 支撑位平均成功率：36.85%
# 压力位平均成功率：31.04%
#
# 成功率分布：
#        support_success  resistance_success
# count       211.000000          211.000000
# mean          0.368483            0.310427
# std           0.267599            0.262017
# min           0.000000            0.000000
# 25%           0.250000            0.000000
# 50%           0.250000            0.250000
# 75%           0.500000            0.500000
# max           1.000000            1.000000
# 856it [00:03, 270.17it/s]
# 回测结果统计（856次有效测试）：
# 支撑位平均成功率：75.14%
# 压力位平均成功率：89.05%
#
# 成功率分布：
#        support_success  resistance_success
# count       856.000000          856.000000
# mean          0.751363            0.890479
# std           0.277453            0.196387
# min           0.000000            0.000000
# 25%           0.500000            0.750000
# 50%           0.750000            1.000000
# 75%           1.000000            1.000000
# max           1.000000            1.000000

# %%
from IPython import get_ipython
from IPython.display import display
# %%
import pandas as pd  # 导入 pandas 用于数据处理
import numpy as np  # 导入 numpy 用于数值计算
from sklearn.cluster import KMeans  # 导入 KMeans 用于聚类
from tqdm import tqdm  # 导入 tqdm 用于进度条显示
from scipy.signal import argrelextrema  # 导入 argrelextrema 用于寻找极值点


class SupportResistanceTester:
    """
    支撑阻力位回测器
    """
    def __init__(self, data_path, window_size=30, test_period=7):
        """
        初始化回测器

        参数:
            data_path (str): 数据文件路径
            window_size (int): 训练窗口大小（默认30个周期）
            test_period (int): 测试周期长度（默认7个周期）
        """
        self.df = self._load_data(data_path)  # 加载数据
        self.window_size = window_size  # 设置训练窗口大小
        self.test_period = test_period  # 设置测试周期长度
        self.results = []  # 存储回测结果

    def _load_data(self, path):
        """
        加载数据文件

        参数:
            path (str): 数据文件路径

        返回:
            pandas.DataFrame: 加载后的数据
        """
        df = pd.read_csv(path, parse_dates=['date'])  # 读取 CSV 文件，并将 'date' 列解析为日期
        df = df.sort_values('date').set_index('date')  # 按日期排序并设置日期为索引
        df = df[~df.index.duplicated(keep='first')]  # 去除重复的索引
        return df

    def _generate_windows(self):
        """
        改进的窗口生成器，生成训练和测试数据窗口

        产出:
            tuple: 训练数据窗口和测试数据窗口
        """
        dates = self.df.index  # 获取所有日期
        total_length = len(dates)  # 获取日期总数
        step = 1  # 每次滑动1个单位

        for i in range(0, total_length - self.window_size - self.test_period, step):
            train_start = dates[i]  # 训练窗口起始日期
            train_end = dates[i + self.window_size - 1]  # 训练窗口结束日期
            test_start = dates[i + self.window_size]  # 测试窗口起始日期
            test_end = dates[i + self.window_size + self.test_period - 1]  # 测试窗口结束日期

            # 确保测试期有足够数据
            if len(self.df.loc[test_start:test_end]) < self.test_period:
                continue

            train_data = self.df.loc[train_start:train_end]  # 获取训练数据
            test_data = self.df.loc[test_start:test_end]  # 获取测试数据

            yield train_data, test_data  # 产出训练数据和测试数据

    def _find_pivots(self, prices, window=5):
        """
        识别关键拐点（局部高低点）

        参数:
            prices (pandas.Series): 价格序列
            window (int): 用于寻找极值点的窗口大小（默认5）

        返回:
            list: 关键拐点价格列表
        """
        max_idx = argrelextrema(prices.values, np.greater, order=window)[0]  # 寻找局部最大值索引
        min_idx = argrelextrema(prices.values, np.less, order=window)[0]  # 寻找局部最小值索引
        return sorted(prices.iloc[max_idx].tolist() + prices.iloc[min_idx].tolist())  # 返回排序后的关键拐点价格

    def _fibonacci_levels(self, df, lookback=20):
        """
        计算斐波那契回撤位

        参数:
            df (pandas.DataFrame): 数据
            lookback (int): 回溯周期（默认20）

        返回:
            dict: 斐波那契回撤位字典，键为回撤比例，值为价格水平
        """
        recent = df.iloc[-lookback:]  # 获取最近 lookback 个周期的数据
        swing_high = recent['high'].max()  # 获取近期最高价
        swing_low = recent['low'].min()  # 获取近期最低价
        delta = swing_high - swing_low  # 计算价格波动范围
        return {
            0.236: swing_high - delta * 0.236,  # 计算 0.236 回撤位
            0.382: swing_high - delta * 0.382,  # 计算 0.382 回撤位
            0.5: swing_high - delta * 0.5,  # 计算 0.5 回撤位
            0.618: swing_high - delta * 0.618,  # 计算 0.618 回撤位
            0.786: swing_high - delta * 0.786  # 计算 0.786 回撤位
        }

    def _cluster_levels(self, levels):
        """
        使用 K-means 聚类关键点位

        参数:
            levels (list): 关键点位列表

        返回:
            list: 聚类后的关键点位列表
        """
        if len(levels) < 3:  # 如果关键点位少于3个，直接返回排序后的列表
            return sorted(levels)
        X = np.array(levels).reshape(-1, 1)  # 将关键点位转换为 numpy 数组
        kmeans = KMeans(n_clusters=3, random_state=0).fit(X)  # 使用 KMeans 聚类
        return sorted([round(x[0], 2) for x in kmeans.cluster_centers_])  # 返回聚类中心，保留两位小数

    def _calculate_levels(self, df, freq='daily'):
        """
        综合计算支撑压力位，使用多种方法

        参数:
            df (pandas.DataFrame): 数据
            freq (str): 数据频率（默认 'daily'）

        返回:
            dict: 支撑压力位字典，包含 'support' 和 'resistance' 两个键
        """
        methods = {}  # 存储不同方法计算的支撑阻力位

        # 方法1：整数关口
        current_price = df['close'].iloc[-1]  # 获取当前收盘价
        methods['round_number'] = {
            'support': [np.floor(current_price / 100) * 100],  # 计算整数关口支撑位
            'resistance': [np.ceil(current_price / 100) * 100]  # 计算整数关口阻力位
        }

        # 方法2：近期高低点
        methods['recent_extreme'] = {
            'support': [df['low'].rolling(20).min().iloc[-1]],  # 计算近期最低价作为支撑位
            'resistance': [df['high'].rolling(20).max().iloc[-1]]  # 计算近期最高价作为阻力位
        }

        # 方法3：斐波那契
        fib = self._fibonacci_levels(df)  # 计算斐波那契回撤位
        methods['fibonacci'] = {
            'support': [fib[0.618]],  # 使用 0.618 回撤位作为支撑位
            'resistance': [fib[0.382]]  # 使用 0.382 回撤位作为阻力位
        }

        # 方法4：布林带
        ma20 = df['close'].rolling(20).mean()  # 计算20周期移动平均线
        std = df['close'].rolling(20).std()  # 计算20周期标准差
        methods['bollinger'] = {
            'support': [ma20.iloc[-1] - 2 * std.iloc[-1]],  # 计算布林带下轨作为支撑位
            'resistance': [ma20.iloc[-1] + 2 * std.iloc[-1]]  # 计算布林带上轨作为阻力位
        }

        # 方法5：波动率通道
        atr = df['high'].rolling(14).max() - df['low'].rolling(14).min()  # 计算14周期平均真实波动范围 (ATR)
        methods['vol_channel'] = {
            'support': [current_price - atr.iloc[-1]],  # 计算波动率通道下轨作为支撑位
            'resistance': [current_price + atr.iloc[-1]]  # 计算波动率通道上轨作为阻力位
        }

        # 综合所有方法
        all_support = []  # 存储所有方法计算的支撑位
        all_resistance = []  # 存储所有方法计算的阻力位
        for method in methods.values():
            all_support += method['support']
            all_resistance += method['resistance']

        # 聚类分析
        return {
            'support': self._cluster_levels(all_support),  # 对支撑位进行聚类
            'resistance': self._cluster_levels(all_resistance)  # 对阻力位进行聚类
        }

    def _test_levels(self, levels, test_data):
        """
        改进的验证方法，测试支撑阻力位的有效性

        参数:
            levels (dict): 支撑阻力位字典
            test_data (pandas.DataFrame): 测试数据

        返回:
            dict: 支撑阻力位成功率字典
        """
        if not levels['support'] or not levels['resistance']:  # 如果没有支撑位或阻力位，返回成功率为0
            return {'support_success': 0, 'resistance_success': 0}

        # 支撑位验证
        support_hits = 0  # 支撑位击中次数
        for s in levels['support']:
            touch = test_data['low'] <= s * 1.01  # 1%容差，判断价格是否触及支撑位
            if touch.any():  # 如果价格触及支撑位
                touch_idx = touch.idxmax()  # 获取触及支撑位的索引
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取触及支撑位后一个周期的收盘价
                    if next_close > s * 0.99:  # 反弹确认，判断价格是否反弹
                        support_hits += 1  # 支撑位击中次数加1

        # 压力位验证
        resistance_hits = 0  # 压力位击中次数
        for r in levels['resistance']:
            touch = test_data['high'] >= r * 0.99  # 1%容差，判断价格是否触及压力位
            if touch.any():  # 如果价格触及压力位
                touch_idx = touch.idxmax()  # 获取触及压力位的索引
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取触及压力位后一个周期的收盘价
                    if next_close < r * 1.01:  # 回落确认，判断价格是否回落
                        resistance_hits += 1  # 压力位击中次数加1

        return {
            'support_success': support_hits / len(levels['support']),  # 计算支撑位成功率
            'resistance_success': resistance_hits / len(levels['resistance'])  # 计算压力位成功率
        }

    def run_backtest(self):
        """
        改进的回测执行，对所有窗口进行回测

        返回:
            pandas.DataFrame: 回测结果数据框
        """
        for train_data, test_data in tqdm(self._generate_windows()):  # 遍历所有窗口
            levels = self._calculate_levels(train_data)  # 计算支撑阻力位
            result = self._test_levels(levels, test_data)  # 测试支撑阻力位

            self.results.append({  # 将结果添加到结果列表
                'train_start': train_data.index[0],  # 训练窗口起始日期
                'train_end': train_data.index[-1],  # 训练窗口结束日期
                'test_start': test_data.index[0],  # 测试窗口起始日期
                'test_end': test_data.index[-1],  # 测试窗口结束日期
                'levels': levels,  # 支撑阻力位
                **result  # 支撑阻力位成功率
            })

        return self._analyze_results()  # 分析回测结果

    def _analyze_results(self):
        """
        改进的结果分析，统计回测结果

        返回:
            pandas.DataFrame: 回测结果数据框
        """
        df = pd.DataFrame(self.results)  # 将结果列表转换为数据框

        # 过滤无效测试
        df = df[(df['support_success'] >= 0) & (df['resistance_success'] >= 0)]  # 过滤成功率小于0的测试

        if len(df) == 0:  # 如果没有有效的测试结果，打印提示信息并返回 None
            print("没有有效的测试结果")
            return None

        print(f"\n回测结果统计（{len(df)}次有效测试）：")  # 打印回测结果统计信息
        print(f"支撑位平均成功率：{df['support_success'].mean():.2%}")  # 打印支撑位平均成功率
        print(f"压力位平均成功率：{df['resistance_success'].mean():.2%}")  # 打印压力位平均成功率

        # 成功率分布
        print("\n成功率分布：")  # 打印成功率分布信息
        print(df[['support_success', 'resistance_success']].describe())  # 打印成功率的描述性统计信息

        return df

    def print_latest_levels(self):
        """
        打印最新的支撑压力位

        返回:
            dict: 最新支撑压力位字典
        """
        # 获取最新的训练窗口数据
        latest_data = self.df.iloc[-self.window_size:]  # 获取最近 window_size 个周期的数据
        levels = self._calculate_levels(latest_data)  # 计算支撑阻力位
        current_price = self.df['close'].iloc[-1]  # 获取当前收盘价

        print("\n=== 最新支撑压力位分析 ===")  # 打印标题
        print(f"当前价格: {current_price:.2f}")  # 打印当前价格
        print(f"分析时间: {self.df.index[-1]}")  # 打印分析时间

        # 打印支撑位
        print("\n支撑位:")  # 打印标题
        for level in sorted(levels['support'], reverse=True):  # 遍历支撑位，从大到小排序
            distance = (current_price - level) / current_price * 100  # 计算支撑位与当前价格的距离（百分比）
            if distance > 0:  # 如果支撑位低于当前价格
                print(f"{level:.2f} (距当前价格向下: {distance:.2f}%)")  # 打印支撑位和距离
            else:  # 如果支撑位高于当前价格
                print(f"{level:.2f} (距当前价格向上: {abs(distance):.2f}%)")  # 打印支撑位和距离

        # 打印压力位
        print("\n压力位:")  # 打印标题
        for level in sorted(levels['resistance']):  # 遍历压力位，从小到大排序
            distance = (level - current_price) / current_price * 100  # 计算压力位与当前价格的距离（百分比）
            print(f"{level:.2f} (距当前价格向上: {distance:.2f}%)")  # 打印压力位和距离

        return levels

    def plot_levels(self):
        """
        绘制价格走势和支撑压力位图表
        """
        import matplotlib.pyplot as plt  # 导入 matplotlib 用于绘图
        from matplotlib.gridspec import GridSpec  # 导入 GridSpec 用于布局

        # 获取最新的数据和水平
        plot_data = self.df.iloc[-self.window_size * 2:]  # 获取最近 window_size * 2 个周期的数据
        levels = self._calculate_levels(self.df.iloc[-self.window_size:])  # 计算支撑阻力位
        current_price = plot_data['close'].iloc[-1]  # 获取当前收盘价

        # 创建图表
        fig = plt.figure(figsize=(15, 10))  # 创建图表对象
        gs = GridSpec(2, 1, height_ratios=[3, 1])  # 创建 GridSpec 对象

        # 主图：价格和支撑压力位
        ax1 = fig.add_subplot(gs[0])  # 创建主图
        ax2 = fig.add_subplot(gs[1])

        # 绘制价格
        ax1.plot(plot_data.index, plot_data['close'], label='收盘价', color='black', linewidth=1)  # 绘制收盘价曲线
        ax1.fill_between(plot_data.index, plot_data['high'], plot_data['low'],
                        color='lightgray', alpha=0.3, label='价格区间')  # 填充价格区间

        # 绘制支撑位
        for level in levels['support']:
            ax1.axhline(y=level, color='green', linestyle='--', alpha=0.5,
                      label=f'支撑位 {level:.2f}')  # 绘制支撑位水平线

        # 绘制压力位
        for level in levels['resistance']:
            ax1.axhline(y=level, color='red', linestyle='--', alpha=0.5,
                      label=f'压力位 {level:.2f}')  # 绘制压力位水平线

        # 绘制成交量
        ax2.bar(plot_data.index, plot_data['volume'],
                color=['red' if c < o else 'green' for c, o in
                       zip(plot_data['close'], plot_data['open'])],
                alpha=0.6)  # 绘制成交量柱状图

        # 设置标题和标签
        ax1.set_title('价格走势与支撑压力位分析', fontsize=12)  # 设置主图标题
        ax1.set_ylabel('价格', fontsize=10)  # 设置主图 y 轴标签
        ax2.set_ylabel('成交量', fontsize=10)  # 设置成交量图 y 轴标签
        ax2.set_xlabel('时间', fontsize=10)  # 设置成交量图 x 轴标签

        # 添加网格
        ax1.grid(True, linestyle='--', alpha=0.3)  # 添加主图网格
        ax2.grid(True, linestyle='--', alpha=0.3)  # 添加成交量图网格

        # 优化图例
        ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # 设置图例位置

        # 添加当前价格标注
        ax1.axhline(y=current_price, color='blue', linestyle='-', alpha=0.3)  # 绘制当前价格水平线
        ax1.text(plot_data.index[-1], current_price, f' 当前价格: {current_price:.2f}',
                verticalalignment='bottom')  # 添加当前价格文本标注

        # 自动调整布局
        plt.tight_layout()  # 自动调整布局
        plt.show()  # 显示图表

    def analyze_current_market(self):
        """
        分析当前市场状态，包括支撑阻力位、趋势和波动率

        返回:
            dict: 当前市场状态字典
        """
        latest_data = self.df.iloc[-self.window_size:]  # 获取最近 window_size 个周期的数据
        levels = self._calculate_levels(latest_data)  # 计算支撑阻力位
        current_price = self.df['close'].iloc[-1]  # 获取当前收盘价

        # 打印当前分析结果
        self.print_latest_levels()  # 打印最新的支撑压力位

        # 绘制图表
        self.plot_levels()  # 绘制价格走势和支撑压力位图表

        # 计算趋势强度
        ma20 = latest_data['close'].rolling(20).mean().iloc[-1]  # 计算20周期移动平均线
        ma50 = latest_data['close'].rolling(50).mean().iloc[-1]  # 计算50周期移动平均线

        print("\n=== 市场趋势分析 ===")  # 打印标题
        if current_price > ma20 > ma50:  # 如果当前价格高于20周期均线且20周期均线高于50周期均线
            print("当前趋势: 上升趋势")  # 打印上升趋势
        elif current_price < ma20 < ma50:  # 如果当前价格低于20周期均线且20周期均线低于50周期均线
            print("当前趋势: 下降趋势")  # 打印下降趋势
        else:  # 否则
            print("当前趋势: 盘整")  # 打印盘整

        # 计算波动率
        atr = (latest_data['high'] - latest_data['low']).rolling(14).mean().iloc[-1]  # 计算14周期平均真实波动范围 (ATR)
        print(f"当前波动率 (ATR): {atr:.2f}")  # 打印波动率

        return {
            'levels': levels,  # 支撑阻力位
            'current_price': current_price,  # 当前价格
            'trend': 'up' if current_price > ma20 > ma50 else 'down' if current_price < ma20 < ma50 else 'sideways',
            # 趋势
            'volatility': atr  # 波动率
        }


# 使用示例
if __name__ == "__main__":
    # 日线回测
    daily_tester = SupportResistanceTester(
        data_path='hstech_data_1d.csv',  # 日线数据文件路径
        window_size=30,  # 训练窗口大小为30天
        test_period=5  # 测试周期长度为5天
    )
    daily_results = daily_tester.run_backtest()  # 执行日线回测
    daily_tester.analyze_current_market()  # 分析当前市场状态

    # 小时线回测（需调整参数）
    hourly_tester = SupportResistanceTester(
        data_path='hstech_data_5min.csv',  # 小时线数据文件路径
        window_size=120,  # 训练窗口大小为120小时（5天）
        test_period=24  # 测试周期长度为24小时
    )
    hourly_results = hourly_tester.run_backtest()  # 执行小时线回测
    hourly_tester.analyze_current_market()  # 分析当前市场状态
# Out:
# 211it [00:01, 116.64it/s]
# 回测结果统计（211次有效测试）：
# 支撑位平均成功率：26.54%
# 压力位平均成功率：24.33%
#
# 成功率分布：
#        support_success  resistance_success
# count       211.000000          211.000000
# mean          0.265403            0.243286
# std           0.184358            0.194640
# min           0.000000            0.000000
# 25%           0.000000            0.000000
# 50%           0.333333            0.333333
# 75%           0.333333            0.333333
# max           0.666667            0.666667
#
# === 最新支撑压力位分析 ===
# 当前价格: 5672.24
# 分析时间: 2025-02-19 00:00:00
#
# 支撑位:
# 5600.00 (距当前价格向下: 1.27%)
# 4954.92 (距当前价格向下: 12.65%)
# 4441.91 (距当前价格向下: 21.69%)
#
# 压力位:
# 5238.10 (距当前价格向上: -7.65%)
# 5725.01 (距当前价格向上: 0.93%)
# 6796.10 (距当前价格向上: 19.81%)
# === 市场趋势分析 ===
# 当前趋势: 盘整
# 当前波动率 (ATR): 170.48
# ...

# %%
from IPython import get_ipython
from IPython.display import display
# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from tqdm import tqdm
from scipy.signal import argrelextrema


class SupportResistanceTester:
    """
    支撑阻力位测试器
    """
    def __init__(self, data_path, window_size=30, test_period=7):
        """
        初始化函数

        参数：
            data_path (str): 数据文件路径
            window_size (int): 训练窗口大小（默认30）
            test_period (int): 测试周期长度（默认7）
        """
        self.df = self._load_data(data_path)  # 加载数据
        self.window_size = window_size  # 设置训练窗口大小
        self.test_period = test_period  # 设置测试周期长度
        self.results = []  # 存储回测结果

    def _load_data(self, path):
        """
        加载数据

        参数：
            path (str): 数据文件路径

        返回：
            pd.DataFrame: 加载后的数据
        """
        df = pd.read_csv(path, parse_dates=['date'])  # 读取CSV文件，并将'date'列解析为日期
        df = df.sort_values('date').set_index('date')  # 按日期排序并设置日期为索引
        df = df[~df.index.duplicated(keep='first')]  # 去除重复的索引
        return df

    def _generate_windows(self):
        """
        改进的窗口生成器，生成训练和测试数据窗口

        返回：
            generator: 训练数据和测试数据窗口的生成器
        """
        dates = self.df.index  # 获取日期索引
        total_length = len(dates)  # 获取数据总长度
        step = 1  # 每次滑动1个单位

        for i in range(0, total_length - self.window_size - self.test_period, step):
            # 计算训练和测试窗口的起始和结束日期
            train_start = dates[i]
            train_end = dates[i + self.window_size - 1]
            test_start = dates[i + self.window_size]
            test_end = dates[i + self.window_size + self.test_period - 1]

            # 确保测试期有足够数据
            if len(self.df.loc[test_start:test_end]) < self.test_period:
                continue

            # 获取训练和测试数据
            train_data = self.df.loc[train_start:train_end]
            test_data = self.df.loc[test_start:test_end]

            yield train_data, test_data  # 生成训练和测试数据窗口

    def _find_pivots(self, prices, window=5):
        """
        识别关键拐点（使用argrelextrema函数）

        参数：
            prices (pd.Series): 价格序列
            window (int): 用于识别拐点的窗口大小（默认5）

        返回：
            list: 关键拐点价格列表
        """
        max_idx = argrelextrema(prices.values, np.greater, order=window)[0]  # 找到局部最大值索引
        min_idx = argrelextrema(prices.values, np.less, order=window)[0]  # 找到局部最小值索引
        return sorted(prices.iloc[max_idx].tolist() + prices.iloc[min_idx].tolist())  # 合并并排序拐点价格

    def _fibonacci_levels(self, df, lookback=20):
        """
        计算斐波那契回撤位

        参数：
            df (pd.DataFrame): 数据
            lookback (int): 回溯周期（默认20）

        返回：
            dict: 斐波那契水平字典
        """
        recent = df.iloc[-lookback:]  # 获取最近的数据
        swing_high = recent['high'].max()  # 获取最高价
        swing_low = recent['low'].min()  # 获取最低价
        delta = swing_high - swing_low  # 计算价差
        return {  # 返回斐波那契水平字典
            0.236: swing_high - delta * 0.236,
            0.382: swing_high - delta * 0.382,
            0.5: swing_high - delta * 0.5,
            0.618: swing_high - delta * 0.618,
            0.786: swing_high - delta * 0.786
        }

    def _cluster_levels(self, levels):
        """
        使用K-means聚类关键点位，动态调整聚类数量

        参数：
            levels (list): 关键点位列表

        返回：
            list: 聚类后的关键点位列表
        """
        if len(levels) < 2:  # 如果关键点位少于2个，直接返回
            return sorted(levels)

        # 去重并转换为numpy数组
        unique_levels = np.unique(levels)
        X = unique_levels.reshape(-1, 1)

        # 根据唯一值数量动态确定聚类数
        n_clusters = min(3, len(unique_levels))

        if n_clusters < 2:  # 如果聚类数小于2，直接返回
            return sorted(unique_levels.tolist())

        try:
            kmeans = KMeans(n_clusters=n_clusters, random_state=0, n_init=10)  # 初始化KMeans模型
            kmeans.fit(X)  # 拟合模型
            return sorted([round(x[0], 2) for x in kmeans.cluster_centers_])  # 返回聚类中心
        except Exception as e:
            print(f"聚类过程出现错误: {e}")  # 打印错误信息
            return sorted(unique_levels.tolist())  # 返回原始点位

    def _calculate_levels(self, df, freq='daily'):
        """
        改进的支撑压力位计算方法，综合多种方法

        参数：
            df (pd.DataFrame): 数据
            freq (str): 数据频率（默认'daily'）

        返回：
            dict: 包含支撑位和压力位的字典
        """
        methods = {}  # 存储不同方法计算的支撑阻力位
        current_price = df['close'].iloc[-1]  # 获取当前价格

        # 方法1：整数关口（优化计算）
        price_magnitude = 10 ** (len(str(int(current_price))) - 2)  # 计算价格数量级
        methods['round_number'] = {
            'support': [np.floor(current_price / price_magnitude) * price_magnitude],  # 计算支撑位
            'resistance': [np.ceil(current_price / price_magnitude) * price_magnitude]  # 计算压力位
        }

        # 方法2：近期高低点（增加多个周期）
        windows = [5, 10, 20]  # 设置窗口大小
        support_levels = []  # 存储支撑位
        resistance_levels = []  # 存储压力位
        for window in windows:
            support_levels.append(df['low'].rolling(window).min().iloc[-1])  # 计算滚动窗口最低价
            resistance_levels.append(df['high'].rolling(window).max().iloc[-1])  # 计算滚动窗口最高价
        methods['recent_extreme'] = {
            'support': support_levels,
            'resistance': resistance_levels
        }

        # 方法3：斐波那契（增加更多水平）
        fib = self._fibonacci_levels(df)  # 计算斐波那契水平
        methods['fibonacci'] = {
            'support': [fib[level] for level in [0.618, 0.786]],  # 获取支撑位
            'resistance': [fib[level] for level in [0.382, 0.236]]  # 获取压力位
        }

        # 方法4：布林带（增加多个标准差）
        ma20 = df['close'].rolling(20).mean().iloc[-1]  # 计算20日均线
        std = df['close'].rolling(20).std().iloc[-1]  # 计算20日标准差
        methods['bollinger'] = {
            'support': [ma20 - std * multiplier for multiplier in [1.5, 2, 2.5]],  # 计算支撑位
            'resistance': [ma20 + std * multiplier for multiplier in [1.5, 2, 2.5]]  # 计算压力位
        }

        # 方法5：波动率通道（改进计算方法）
        atr = self._calculate_atr(df)  # 计算ATR
        methods['vol_channel'] = {
            'support': [current_price - multiplier * atr for multiplier in [1, 1.5]],  # 计算支撑位
            'resistance': [current_price + multiplier * atr for multiplier in [1, 1.5]]  # 计算压力位
        }

        # 综合所有方法
        all_support = []  # 存储所有支撑位
        all_resistance = []  # 存储所有压力位
        for method in methods.values():
            all_support.extend(method['support'])  # 添加支撑位
            all_resistance.extend(method['resistance'])  # 添加压力位

        # 移除无效值并聚类
        all_support = [x for x in all_support if not np.isnan(x)]  # 移除无效值
        all_resistance = [x for x in all_resistance if not np.isnan(x)]  # 移除无效值

        return {  # 返回聚类后的支撑阻力位
            'support': self._cluster_levels(all_support),
            'resistance': self._cluster_levels(all_resistance)
        }

    def _calculate_atr(self, df, period=14):
        """
        计算平均真实波动范围 (ATR)

        参数：
            df (pd.DataFrame): 数据
            period (int): 计算周期（默认14）

        返回：
            float: ATR值
        """
        high = df['high']  # 获取最高价
        low = df['low']  # 获取最低价
        close = df['close'].shift(1)  # 获取前一日收盘价

        tr1 = high - low  # 计算真实波动范围1
        tr2 = abs(high - close)  # 计算真实波动范围2
        tr3 = abs(low - close)  # 计算真实波动范围3
        tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)  # 取三者最大值

        return tr.rolling(period).mean().iloc[-1]  # 计算ATR

    def print_latest_levels(self):
        """
        打印最新的支撑压力位（增加更多信息）
        """
        latest_data = self.df.iloc[-self.window_size:]  # 获取最新的数据
        levels = self._calculate_levels(latest_data)  # 计算支撑阻力位
        current_price = self.df['close'].iloc[-1]  # 获取当前价格

        print("\n=== 最新支撑压力位分析 ===")  # 打印标题
        print(f"当前价格: {current_price:.2f}")  # 打印当前价格
        print(f"分析时间: {self.df.index[-1]}")  # 打印分析时间

        # 计算强度指标
        price_volatility = latest_data['close'].pct_change().std()  # 计算价格波动率
        volume_trend = latest_data['volume'].iloc[-5:].mean() / latest_data['volume'].iloc[-20:].mean()  # 计算成交量趋势

        # 打印支撑位
        print("\n支撑位 (按重要性排序):")
        for level in sorted(levels['support'], reverse=True):
            distance = (current_price - level) / current_price * 100  # 计算距离当前价格的百分比
            strength = self._calculate_level_strength(level, latest_data)  # 计算强度
            if distance > 0:
                print(f"{level:.2f} (向下: {distance:.2f}%, 强度: {strength:.2f})")  # 打印支撑位信息
            else:
                print(f"{level:.2f} (向上: {abs(distance):.2f}%, 强度: {strength:.2f})")  # 打印支撑位信息

        # 打印压力位
        print("\n压力位 (按重要性排序):")
        for level in sorted(levels['resistance']):
            distance = (level - current_price) / current_price * 100  # 计算距离当前价格的百分比
            strength = self._calculate_level_strength(level, latest_data)  # 计算强度
            print(f"{level:.2f} (向上: {distance:.2f}%, 强度: {strength:.2f})")  # 打印压力位信息

        # 打印市场环境指标
        print(f"\n市场波动率: {price_volatility:.4f}")  # 打印市场波动率
        print(f"成交量趋势: {'上升' if volume_trend > 1.1 else '下降' if volume_trend < 0.9 else '平稳'}")  # 打印成交量趋势

        return levels

    def _calculate_level_strength(self, level, df):
        """
        计算价格水平的强度

        参数：
            level (float): 价格水平
            df (pd.DataFrame): 数据

        返回：
            float: 强度得分
        """
        # 计算与价格的接触次数
        price_range = df['high'] - df['low']  # 计算价格范围
        avg_range = price_range.mean()  # 计算平均价格范围
        tolerance = avg_range * 0.1  # 设置容差

        touches = ((df['low'] - level).abs() <= tolerance) | ((df['high'] - level).abs() <= tolerance)  # 判断是否触及价格水平
        touch_count = touches.sum()  # 计算触及次数

        # 计算成交量支持
        volume_near_level = df.loc[touches, 'volume'].mean() if touch_count > 0 else 0  # 计算触及价格水平时的平均成交量
        avg_volume = df['volume'].mean()  # 计算平均成交量
        volume_factor = min(volume_near_level / avg_volume if avg_volume > 0 else 0, 2)  # 计算成交量因子

        # 计算最终强度得分 (0-1之间)
        max_touches = len(df) * 0.2  # 假设最多20%的时间点发生接触
        touch_score = min(touch_count / max_touches, 1)  # 计算触及得分

        strength = (touch_score * 0.7 + volume_factor * 0.3)  # 计算最终强度得分
        return round(strength, 2)



    def _test_levels(self, levels, test_data):
        """
        改进的验证方法，验证支撑阻力位的有效性

        参数：
            levels (dict): 包含支撑位和压力位的字典
            test_data (pd.DataFrame): 测试数据

        返回：
            dict: 包含支撑位和压力位成功率的字典
        """
        if not levels['support'] or not levels['resistance']:  # 如果没有支撑位或压力位，返回0成功率
            return {'support_success': 0, 'resistance_success': 0}

        # 支撑位验证
        support_hits = 0  # 初始化支撑位触及次数
        for s in levels['support']:
            touch = test_data['low'] <= s * 1.01  # 1%容差，判断是否触及支撑位
            if touch.any():  # 如果触及
                touch_idx = touch.idxmax()  # 获取触及的时间点
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取下一个收盘价
                    if next_close > s * 0.99:  # 反弹确认
                        support_hits += 1  # 触及次数加1

        # 压力位验证
        resistance_hits = 0  # 初始化压力位触及次数
        for r in levels['resistance']:
            touch = test_data['high'] >= r * 0.99  # 1%容差，判断是否触及压力位
            if touch.any():  # 如果触及
                touch_idx = touch.idxmax()  # 获取触及的时间点
                if touch_idx < test_data.index[-1]:  # 确保有后续数据
                    next_close = test_data.loc[touch_idx:]['close'].iloc[1]  # 获取下一个收盘价
                    if next_close < r * 1.01:  # 回落确认
                        resistance_hits += 1  # 触及次数加1

        return {  # 返回支撑位和压力位成功率
            'support_success': support_hits / len(levels['support']),
            'resistance_success': resistance_hits / len(levels['resistance'])
        }

    def run_backtest(self):
        """
        改进的回测执行，对所有数据窗口进行测试

        返回：
            pd.DataFrame: 回测结果
        """
        for train_data, test_data in tqdm(self._generate_windows()):  # 遍历所有数据窗口
            levels = self._calculate_levels(train_data)  # 计算支撑阻力位
            result = self._test_levels(levels, test_data)  # 验证支撑阻力位

            self.results.append({  # 保存回测结果
                'train_start': train_data.index[0],
                'train_end': train_data.index[-1],
                'test_start': test_data.index[0],
                'test_end': test_data.index[-1],
                'levels': levels,
                **result
            })

        return self._analyze_results()  # 分析回测结果

    def _analyze_results(self):
        """
        改进的结果分析，统计回测结果

        返回：
            pd.DataFrame: 回测结果统计
        """
        df = pd.DataFrame(self.results)  # 将回测结果转换为DataFrame

        # 过滤无效测试
        df = df[(df['support_success'] >= 0) & (df['resistance_success'] >= 0)]  # 过滤无效测试

        if len(df) == 0:  # 如果没有有效测试，打印提示信息
            print("没有有效的测试结果")
            return None

        print(f"\n回测结果统计（{len(df)}次有效测试）：")  # 打印回测结果统计
        print(f"支撑位平均成功率：{df['support_success'].mean():.2%}")  # 打印支撑位平均成功率
        print(f"压力位平均成功率：{df['resistance_success'].mean():.2%}")  # 打印压力位平均成功率

        # 成功率分布
        print("\n成功率分布：")  # 打印成功率分布
        print(df[['support_success', 'resistance_success']].describe())  # 打印成功率分布描述

        return df

    def print_latest_levels(self):
        """
        打印最新的支撑压力位
        """
        # 获取最新的训练窗口数据
        latest_data = self.df.iloc[-self.window_size:]  # 获取最新的数据
        levels = self._calculate_levels(latest_data)  # 计算支撑阻力位
        current_price = self.df['close'].iloc[-1]  # 获取当前价格

        print("\n=== 最新支撑压力位分析 ===")  # 打印标题
        print(f"当前价格: {current_price:.2f}")  # 打印当前价格
        print(f"分析时间: {self.df.index[-1]}")  # 打印分析时间

        # 打印支撑位
        print("\n支撑位:")
        for level in sorted(levels['support'], reverse=True):
            distance = (current_price - level) / current_price * 100  # 计算距离当前价格的百分比
            if distance > 0:
                print(f"{level:.2f} (距当前价格向下: {distance:.2f}%)")  # 打印支撑位信息
            else:
                print(f"{level:.2f} (距当前价格向上: {abs(distance):.2f}%)")  # 打印支撑位信息

        # 打印压力位
        print("\n压力位:")
        for level in sorted(levels['resistance']):
            distance = (level - current_price) / current_price * 100  # 计算距离当前价格的百分比
            print(f"{level:.2f} (距当前价格向上: {distance:.2f}%)")  # 打印压力位信息

        return levels

    def plot_levels(self):
        """
        绘制价格走势和支撑压力位
        """
        import matplotlib.pyplot as plt
        from matplotlib.gridspec import GridSpec

        # 获取最新的数据和水平
        plot_data = self.df.iloc[-self.window_size*2:]  # 获取最新的数据
        levels = self._calculate_levels(self.df.iloc[-self.window_size:])  # 计算支撑阻力位
        current_price = plot_data['close'].iloc[-1]  # 获取当前价格

        # 创建图表
        fig = plt.figure(figsize=(15, 10))  # 创建图表
        gs = GridSpec(2, 1, height_ratios=[3, 1])  # 设置图表布局

        # 主图：价格和支撑压力位
        ax1 = fig.add_subplot(gs[0])  # 添加主图
        ax2 = fig.add_subplot(gs[1])
        # 绘制价格
        ax1.plot(plot_data.index, plot_data['close'], label='收盘价', color='black', linewidth=1)  # 绘制收盘价曲线
        ax1.fill_between(plot_data.index, plot_data['high'], plot_data['low'],
                        color='lightgray', alpha=0.3, label='价格区间')  # 填充价格区间

        # 绘制支撑位
        for level in levels['support']:
            ax1.axhline(y=level, color='green', linestyle='--', alpha=0.5,
                      label=f'支撑位 {level:.2f}')  # 绘制支撑位水平线

        # 绘制压力位
        for level in levels['resistance']:
            ax1.axhline(y=level, color='red', linestyle='--', alpha=0.5,
                      label=f'压力位 {level:.2f}')  # 绘制压力位水平线

        # 绘制成交量
        ax2.bar(plot_data.index, plot_data['volume'],
                color=['red' if c < o else 'green' for c, o in zip(plot_data['close'], plot_data['open'])],
                alpha=0.6)  # 绘制成交量柱状图

        # 设置标题和标签
        ax1.set_title('价格走势与支撑压力位分析', fontsize=12)  # 设置标题
        ax1.set_ylabel('价格', fontsize=10)  # 设置y轴标签
        ax2.set_ylabel('成交量', fontsize=10)  # 设置y轴标签
        ax2.set_xlabel('时间', fontsize=10)  # 设置x轴标签

        # 添加网格
        ax1.grid(True, linestyle='--', alpha=0.3)  # 添加网格
        ax2.grid(True, linestyle='--', alpha=0.3)  # 添加网格

        # 优化图例
        ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # 设置图例位置

        # 添加当前价格标注
        ax1.axhline(y=current_price, color='blue', linestyle='-', alpha=0.3)  # 绘制当前价格水平线
        ax1.text(plot_data.index[-1], current_price, f' 当前价格: {current_price:.2f}',
                verticalalignment='bottom')  # 添加当前价格标注

        # 自动调整布局
        plt.tight_layout()  # 自动调整布局
        plt.show()  # 显示图表

    def analyze_current_market(self):
        """
        分析当前市场状态，包括支撑阻力位、趋势和波动率
        """
        latest_data = self.df.iloc[-self.window_size:]  # 获取最近 window_size 个周期的数据
        levels = self._calculate_levels(latest_data)  # 计算支撑阻力位
        current_price = self.df['close'].iloc[-1]  # 获取当前价格

        # 打印当前分析结果
        self.print_latest_levels()  # 打印支撑阻力位

        # 绘制图表
        self.plot_levels()  # 绘制价格走势和支撑阻力位

        # 计算趋势强度
        ma20 = latest_data['close'].rolling(20).mean().iloc[-1]  # 计算20日均线
        ma50 = latest_data['close'].rolling(50).mean().iloc[-1]  # 计算50日均线

        print("\n=== 市场趋势分析 ===")  # 打印标题
        if current_price > ma20 > ma50:  # 判断趋势
            print("当前趋势: 上升趋势")  # 打印趋势
        elif current_price < ma20 < ma50:  # 判断趋势
            print("当前趋势: 下降趋势")  # 打印趋势
        else:  # 判断趋势
            print("当前趋势: 盘整")  # 打印趋势

        # 计算波动率
        atr = (latest_data['high'] - latest_data['low']).rolling(14).mean().iloc[-1]  # 计算ATR
        print(f"当前波动率 (ATR): {atr:.2f}")  # 打印波动率

        return {  # 返回市场状态分析结果
            'levels': levels,
            'current_price': current_price,
            'trend': 'up' if current_price > ma20 > ma50 else 'down' if current_price < ma20 < ma50 else 'sideways',
            'volatility': atr
        }



# 使用示例
if __name__ == "__main__":
    # 日线回测
    daily_tester = SupportResistanceTester(  # 创建日线回测器
        data_path='hstech_data_1d.csv',  # 设置数据文件路径
        window_size=30,  # 设置训练窗口大小
        test_period=5  # 设置测试周期长度
    )
    daily_results = daily_tester.run_backtest()  # 运行回测
    daily_tester.analyze_current_market()  # 分析当前市场状态

    # 小时线回测（需调整参数）
    hourly_tester = SupportResistanceTester(  # 创建小时线回测器
        data_path='hstech_data_5min.csv',  # 设置数据文件路径
        window_size=120,  # 设置训练窗口大小
        test_period=24  # 设置测试周期长度
    )
    hourly_results = hourly_tester.run_backtest()  # 运行回测
    hourly_tester.analyze_current_market()  # 分析当前市场状态
# Out:
# 211it [00:06, 34.37it/s]
# 回测结果统计（211次有效测试）：
# 支撑位平均成功率：35.55%
# 压力位平均成功率：30.96%
#
# 成功率分布：
#        support_success  resistance_success
# count       211.000000          211.000000
# mean          0.355450            0.309637
# std           0.265345            0.253998
# min           0.000000            0.000000
# 25%           0.000000            0.000000
# 50%           0.333333            0.333333
# 75%           0.666667            0.333333
# max           1.000000            1.000000
#
# === 最新支撑压力位分析 ===
# 当前价格: 5672.24
# 分析时间: 2025-02-19 00:00:00
#
# 支撑位:
# 5420.98 (距当前价格向下: 4.43%)
# 4875.73 (距当前价格向下: 14.04%)
# 4334.72 (距当前价格向下: 23.58%)
#
# 压力位:
# 5325.69 (距当前价格向上: -6.11%)
# 5691.60 (距当前价格向上: 0.34%)
# 5924.06 (距当前价格向上: 4.44%)
# === 市场趋势分析 ===
# 当前趋势: 盘整
# 当前波动率 (ATR): 170.48
# 856it [00:22, 37.75it/s]
# 回测结果统计（856次有效测试）：
# 支撑位平均成功率：77.80%
# 压力位平均成功率：86.94%
#
# 成功率分布：
#        support_success  resistance_success
# count       856.000000          856.000000
# ...
